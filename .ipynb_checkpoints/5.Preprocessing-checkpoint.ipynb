# %%
import requests
import json
from bs4 import BeautifulSoup
import time
import re
import pandas as pd
import numpy as np
from pymongo import MongoClient

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/seungheondoh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
db.collection_names()
# Out:
# /Users/seungheondoh/anaconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['scholar',
#  'wordname',
#  'excel',
#  'ResearchInterest',
#  'professors',
#  'profname',
#  'vector',
#  'finaldb',
#  'scholarworksfront',
#  'professor',
#  'profdata',
#  'aboutdepart',
#  'test1',
#  'Docdb',
#  'keyword']

# %%
client = MongoClient()
db = client.aboutdepart
database = list(db.Docdb.find())
testdf = pd.DataFrame(database)
testdf.head()
# Out:
#                                             Abstract  \
# 0  [Entrepreneurs' decisions to exploit opportuni...
# 1  [Organizations use project teams to lower sear...
# 2  [This paper investigates information leakage f...
# 3  [Studies on the effects of corporate social re...
# 4  [Brand communities and corporate social respon...
#
#                                      Author Keywords                  Name  \
# 0  [nan, Behavioral decision-making; Business gro...  Choi, Young Rok(최영록)
# 1  [expertise awareness; expertise use; knowledge...     Hong, Woonki(홍운기)
# 2  [nan, nan, Business group; Chaebol; Control-ca...     Jung, Kooyul(정구열)
# 3  [annual reports; communication; corporate soci...    Kim, MinChung(김민중)
# 4  [Brand community; Consumer communities; Corpor...       Kim, Molan(김모란)
#
#                                     ResearchInterest  \
# 0  Entrepreneurship, Innovation Strategy, Family ...
# 1  Expertise utilization, Transactive menory syst...
# 2  Accounting Information and capital market, Ana...
# 3  Marketing strategies and their impact on finan...
# 4  Online Database Marketing, Social Media Market...
#
#                                                Title  \
# 0  [Entrepreneurs' decisions to exploit opportuni...
# 1  [Explaining dyadic expertise use in knowledge ...
# 2  [Trading behavior prior to public release of a...
# 3  [CSR and Shareholder Value in the Restaurant I...
# 4  [Consumer Communities Do Well, But Will They D...
#
#                         _id  \
# 0  5bf7bdc420c66c03397b5abd
# 1  5bf7bdc520c66c03397b5abe
# 2  5bf7bdc520c66c03397b5abf
# 3  5bf7bdc520c66c03397b5ac0
# 4  5bf7bdc520c66c03397b5ac1
#
#                                           department  \
# 0  Graduate School of Technology and Innovation M...
# 1            School of Business Administration(경영학부)
# 2  Graduate School of Technology and Innovation M...
# 3            School of Business Administration(경영학부)
# 4            School of Business Administration(경영학부)
#
#                                                 docs  \
# 0  [[Entrepreneurs' decisions to exploit opportun...
# 1  [[Explaining dyadic expertise use in knowledge...
# 2  [[Trading behavior prior to public release of ...
# 3  [[CSR and Shareholder Value in the Restaurant ...
# 4  [[Consumer Communities Do Well, But Will They ...
#
#                                                 text
# 0   Entrepreneurs' decisions to exploit opportuni...
# 1   Explaining dyadic expertise use in knowledge ...
# 2   Trading behavior prior to public release of a...
# 3   CSR and Shareholder Value in the Restaurant I...
# 4   Consumer Communities Do Well, But Will They D...

# %%
client = MongoClient()
db = client.aboutdepart
keyworddb = list(db.keyword.find())

# %%
keyword = []
for i in keyworddb:
    keyword.append(i['keyword'])

# %%
import nltk
patterns = {}
for i in keyword:
    patterns[i] = 'keyword'

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords


def docs_preprocessor(docs):
    tokenizer = RegexpTokenizer(r'\w+')
    

    docs = docs.lower()  # Convert to lowercase.
    docs = tokenizer.tokenize(docs)  # Split into words.
    docs = [w for w in docs if not w in stopwords.words('english')]
    
    # Remove numbers, but not words that contain numbers.
    docs = [token for token in docs if not token.isdigit()]
    
    # Remove words that are only one character.
    docs = [token for token in docs if len(token) > 3]
    
    # Lemmatize all words in documents.
    lemmatizer = WordNetLemmatizer()
    docs = [lemmatizer.lemmatize(token) for token in docs]
  
    return docs

# %%
for idx, i in enumerate(testdf['text']):
    add = docs_preprocessor(i)
    testdf.iloc[idx]['text'] = add

# %%
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
zipdata = zip(testdf['Name'],testdf['text'])

# %%
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in zipdata]

# %%
tagged_data[3]
# Out:
# TaggedDocument(words=['shareholder', 'value', 'restaurant', 'industry', 'role', 'communication', 'annual', 'report', 'study', 'effect', 'corporate', 'social', 'responsibility', 'shareholder', 'value', 'identified', 'communication', 'marketing', 'channel', 'mechanism', 'necessary', 'translate', 'shareholder', 'value', 'study', 'annual', 'report', 'considered', 'primary', 'information', 'source', 'used', 'firm', 'financial', 'stakeholder', 'investor', 'analyst', 'valuation', 'firm', 'specifically', 'study', 'examined', 'whether', 'extent', 'restaurant', 'firm', 'communicate', 'annual', 'report', 'influence', 'effect', 'shareholder', 'value', 'return', 'tobin', 'risk', 'equity', 'holder', 'risk', 'disaggregated', 'distinct', 'type', 'primary', 'nonprimary', 'stakeholder', 'result', 'corroborate', 'communicating', 'nonprimary', 'stakeholder', 'annual', 'report', 'help', 'nonprimary', 'stakeholder', 'increase', 'shareholder', 'value', 'reducing', 'equity', 'holder', 'risk', 'whereas', 'communicating', 'primary', 'stakeholder', 'affect', 'value', 'relevance', 'primary', 'stakeholder', 'change', 'either', 'tobin', 'equity', 'holder', 'risk', 'author', 'annual', 'report', 'communication', 'corporate', 'social', 'responsibility', 'equity', 'holder', 'risk', 'tobin', 'effect', 'corporate', 'social', 'responsibility', 'corporate', 'financial', 'performance', 'competitive', 'action', 'perspective', 'attempt', 'provide', 'nuanced', 'view', 'relationship', 'corporate', 'social', 'responsibility', 'firm', 'financial', 'performance', 'using', 'competitive', 'action', 'perspective', 'argue', 'competitive', 'action', 'considered', 'important', 'contingency', 'determines', 'effect', 'activity', 'firm', 'financial', 'performance', 'using', 'data', 'publicly', 'listed', 'firm', 'software', 'industry', 'found', 'socially', 'responsible', 'activity', 'positive', 'enhance', 'firm', 'financial', 'performance', 'firm', 'competitive', 'action', 'level', 'high', 'whereas', 'socially', 'irresponsible', 'activity', 'negative', 'actually', 'improve', 'firm', 'financial', 'performance', 'competitive', 'action', 'level', 'introducing', 'competitive', 'action', 'important', 'contingency', 'study', 'contributes', 'literature', 'strategic', 'management', 'author', 'competitive', 'action', 'financial', 'performance', 'negative', 'positive', 'pride', 'lead', 'corporate', 'managerial', 'hubris', 'strategic', 'emphasis', 'firm', 'strategic', 'emphasis', 'value', 'creation', 'versus', 'appropriation', 'typically', 'reflected', 'resource', 'allocation', 'advertising', 'central', 'corporate', 'decision', 'significantly', 'influence', 'financial', 'performance', 'however', 'driver', 'decision', 'remain', 'underexplored', 'study', 'identifies', 'significant', 'predictor', 'strategic', 'emphasis', 'namely', 'corporate', 'managerial', 'hubris', 'reveals', 'boundary', 'condition', 'leveraging', 'unique', 'dataset', 'based', 'text', 'mining', 'press', 'release', 'issued', 'firm', 'across', 'year', 'author', 'demonstrate', 'high', 'corporate', 'managerial', 'hubris', 'predicts', 'strategic', 'emphasis', 'advertising', 'relative', 'however', 'effect', 'mitigated', 'significantly', 'firm', 'maturity', 'corporate', 'governance', 'industry', 'level', 'strategic', 'emphasis', 'result', 'provide', 'novel', 'insight', 'effect', 'hubris', 'firm', 'spending', 'situation', 'wherein', 'marketing', 'decision', 'tend', 'subject', 'manager', 'psychological', 'bias', 'mean', 'preventing', 'investment', 'marketing', 'strategy', 'recruitment', 'training', 'manager', 'academy', 'marketing', 'science', 'advertising', 'corporate', 'managerial', 'hubris', 'strategic', 'emphasis', 'corporate', 'social', 'responsibility', 'equity', 'holder', 'risk', 'hospitality', 'industry', 'study', 'examined', 'whether', 'corporate', 'social', 'responsibility', 'enhances', 'firm', 'value', 'shareholder', 'ultimately', 'fund', 'firm', 'initiative', 'specifically', 'investigated', 'relationship', 'activity', 'hosp ...

# %%
import re 
import gensim
from gensim.models import doc2vec
from collections import namedtuple
from random import shuffle

# %%
model = gensim.models.Doc2Vec(vector_size=100, window=10, min_count=1, workers=8, alpha=0.025, min_alpha=0.015, 
                              epochs=20)

#sample=1e-4, negative=5,

#shuffling is better (ot needed at each trianing epoch
shuffle(tagged_data)
#Build vocabulary from a sequence of sentences 
model.build_vocab(tagged_data)
#Update the model’s neural weights from a sequence of sentences
model.train(tagged_data, epochs=model.epochs, total_examples=model.corpus_count)

# %%
model.save("finalmodel")

# %%
model.docvecs.most_similar('Kim, Chajoong(김차중)')
# Out:
# /Users/seungheondoh/anaconda3/envs/python3.6/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Baek, Joon Sang(백준상)(2011-07~2018-03)', 0.7693942785263062),
#  ('Kim, KwanMyung(김관명)', 0.7441676259040833),
#  ('Self, James(SelfJames Andrew)', 0.7251253128051758),
#  ('Kim, Molan(김모란)', 0.6752680540084839),
#  ('Kyung, Gyouhyung(경규형)', 0.6741120219230652),
#  ('Lee, Jacob C.(이채호)', 0.6673786640167236),
#  ('Lim, Chiehyeon(임치현)', 0.6527941226959229),
#  ('Zhang, Lu(ZhangLu)', 0.6354166865348816),
#  ('Jung, Dooyoung(정두영)', 0.6336873769760132),
#  ('Kim, Yeolib(김여립)', 0.6311144828796387)]

# %%
docvector = model.docvecs.doctag_syn0
docvector
# Out:
# /Users/seungheondoh/anaconda3/envs/python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doctag_syn0` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs instead).
#   """Entry point for launching an IPython kernel.
# array([[-1.537788  ,  1.5102843 ,  0.2607431 , ..., -3.518449  ,
#          6.5556087 ,  4.8289037 ],
#        [ 2.2451725 , -2.3970385 ,  2.9198055 , ...,  2.6760812 ,
#          4.596075  ,  1.1606504 ],
#        [ 6.9233403 , -5.736098  ,  0.16793114, ..., -4.116905  ,
#          2.4459033 ,  3.0600104 ],
#        ...,
#        [-2.1978292 , -7.889627  ,  3.875637  , ...,  0.6845216 ,
#         10.45687   , -0.06114742],
#        [ 2.9762397 , -3.4917536 ,  4.3288064 , ..., -0.42006868,
#          0.7704472 , -2.1497614 ],
#        [-0.8564529 , -2.608286  ,  1.1805831 , ...,  0.6910298 ,
#          0.606545  , -3.20527   ]], dtype=float32)

# %%
model.docvecs.doctags
# Out:
# {'Lee, Deokjung(이덕중)': Doctag(offset=0, word_count=7744, doc_count=1),
#  'Kwon, Young-Nam(권영남)': Doctag(offset=1, word_count=6745, doc_count=1),
#  'Song, Chang-Keun(송창근)': Doctag(offset=2, word_count=7635, doc_count=1),
#  'Lee, Sukbin(이석빈)': Doctag(offset=3, word_count=3370, doc_count=1),
#  'Park, Tae Joo(박태주)': Doctag(offset=4, word_count=2068, doc_count=1),
#  'Baek, Joon Sang(백준상)(2011-07~2018-03)': Doctag(offset=5, word_count=989, doc_count=1),
#  'Kim, Jaai(김자애)': Doctag(offset=6, word_count=6645, doc_count=1),
#  'Im, Jungho(임정호)': Doctag(offset=7, word_count=13833, doc_count=1),
#  'Hong, Woonki(홍운기)': Doctag(offset=8, word_count=527, doc_count=1),
#  'Kwon, Taejoon(권태준)': Doctag(offset=9, word_count=2900, doc_count=1),
#  'Lee, Zonghoon(이종훈)': Doctag(offset=10, word_count=12657, doc_count=1),
#  'Jang, Hyunjin(장현진)': Doctag(offset=11, word_count=597, doc_count=1),
#  'Sim, Jae-Young(심재영)': Doctag(offset=12, word_count=6144, doc_count=1),
#  'Comuzzi, Marco(ComuzziMarco)': Doctag(offset=13, word_count=6493, doc_count=1),
#  'Lee, Jongwon(이종원)': Doctag(offset=14, word_count=2141, doc_count=1),
#  'Lee, Chang Hyeong(이창형)': Doctag(offset=15, word_count=2201, doc_count=1),
#  'Hur, Min Sup(허민섭)': Doctag(offset=16, word_count=7223, doc_count=1),
#  'Ahn, Sangjoon(안상준)': Doctag(offset=17, word_count=915, doc_count=1),
#  'Joo, Changhee(주창희)': Doctag(offset=18, word_count=8545, doc_count=1),
#  'Kim, Donghyuk(김동혁)': Doctag(offset=19, word_count=3535, doc_count=1),
#  'Bhak, Jong(박종화)': Doctag(offset=20, word_count=13879, doc_count=1),
#  'Park, Noejung(박노정)': Doctag(offset=21, word_count=12215, doc_count=1),
#  'Kwak, Youngshin(곽영신)': Doctag(offset=22, word_count=5367, doc_count=1),
#  'Jung, Dooyoung(정두영)': Doctag(offset=23, word_count=2107, doc_count=1),
#  'Ko, Hyunhyub(고현협)': Doctag(offset=24, word_count=9710, doc_count=1),
#  'Kim, Jooha(김주하)': Doctag(offset=25, word_count=933, doc_count=1),
#  'Lee, Changwook(이창욱)': Doctag(offset=26, word_count=2439, doc_count=1),
#  'Oh, Yoon Seok(오윤석)': Doctag(offset=27, word_count=4286, doc_count=1),
#  'Kim, Yong Hwan(김용환)': Doctag(offset=28, word_count=10287, doc_count=1),
#  'Nam, Dougu(남덕우)': Doctag(offset=29, word_count=2672, doc_count=1),
#  'Cha, Dong-Hyun(차동현)': Doctag(offset=30, word_count=5306, doc_count=1),
#  'Tlusty, Tsvi(TlustyTsvi)': Doctag(offset=31, word_count=7092, doc_count=1),
#  'Lee, Kyunghan(이경한)': Doctag(offset=32, word_count=5395, doc_count=1),
#  'Ding, Feng(DingFeng)': Doctag(offset=33, word_count=12053, doc_count=1),
#  'Myung, Kyungjae(명경재)': Doctag(offset=34, word_count=9148, doc_count=1),
#  'Choi, Sung-Deuk(최성득)': Doctag(offset=35, word_count=10842, doc_count=1),
#  'Cho, Jaeweon(조재원)': Doctag(offset=36, word_count=22403, doc_count=1),
#  'Ko, Myunggon(고명곤)': Doctag(offset=37, word_count=3128, doc_count=1),
#  'Kang, Sarah M.(강사라)': Doctag(offset=38, word_count=6174, doc_count=1),
#  'Chae, Han Gi(채한기)': Doctag(offset=39, word_count=5343, doc_count=1),
#  'Park, Cheol-Min(박철민)': Doctag(offset=40, word_count=1848, doc_count=1),
#  'Shin, Myoungsu(신명수)': Doctag(offset=41, word_count=6280, doc_count=1),
#  'Min, Seung Kyu(민승규)': Doctag(offset=42, word_count=3137, doc_count=1),
#  'Jung, Jee-Hoon(정지훈)': Doctag(offset=43, word_count=7931, doc_count=1),
#  'Yun, Aaram(윤아람)': Doctag(offset=44, word_count=1173, doc_count=1),
#  'Choi, Young-Ri(최영리)': Doctag(offset=45, word_count=1745, doc_count=1),
#  'Jeong, Kyeong-Min(정경민)': Doctag(offset=46, word_count=563, doc_count=1),
#  'Noh, Sam H.(노삼혁)': Doctag(offset=47, word_count=9904, doc_count=1),
#  'Kyung, Gyouhyung(경규형)': Doctag(offset=48, word_count=3364, doc_count=1),
#  'Kwak, Sang Kyu(곽상규)': Doctag(offset=49, word_count=13087, doc_count=1),
#  'Kim, Chajoong(김차중)': Doctag(offset=50, word_count=1836, doc_count=1),
#  'Moon, Hoi Ri(문회리)': Doctag(offset=51, word_count=4427, doc_count=1),
#  'Lee, Young-Joo(이영주)': Doctag(offset=52, word_count=4178, doc_count=1),
#  'Choi, Jaesik(최재식)': Doctag(offset=53, word_count=4054, doc_count=1),
#  'Lee, Changyong(이창용)': Doctag(offset=54, word_count=4876, doc_count=1),
#  'Kim, Hak Sun(김학선)': Doctag(offset=55, word_count=3417, doc_count=1),
#  'Ruoff, Rodney S.(RuoffRodney Scott)': Doctag(offset=56, word_count=45307, doc_count=1),
#  'Granick, Steve(GranickSteve)': Doctag(offset=57, word_count=25393, doc_count=1),
#  'Cho, Hyungjoon(조형준)': Doctag(offset=58, word_count=4653, doc_count=1),
#  'Choi, Jaehyouk(최재혁)': Doctag(offset=59, word_count=2467, doc_count=1),
#  'Chun, Se Young(전세영)': Doctag(offset=60, word_count=4987, doc_count=1),
#  'Lee, Myong-In(이명인)': Doctag(offset=61, word_count=9663, doc_count=1),
#  'Scharer, Orlando D.(ScharerDavid Orlando)': Doctag(offset=62, word_count=8395, doc_count=1),
#  'Kim, Sung-Phil(김성필)': Doctag(offset=63, word_count=14246, doc_count=1),
#  'Bien, Franklin(변영재)': Doctag(offset=64, word_count=8236, doc_count=1),
#  'Lee, Myunghee(이명희)': Doctag(offset=65, word_count=1784, doc_count=1),
#  'Oh, Jae Eun(오재은)': Doctag(offset=66, word_count=3742, doc_count=1),
#  'Lee, Dong Woog(이동욱)': Doctag(offset=67, word_count=3105, doc_count=1),
#  'Kang, Byoung Heon(강병헌)': Doctag(offset=68, word_count=2963, doc_count=1),
#  'Park, Sung Soo(박성수)': Doctag(offset=69, word_count=4887, doc_count=1),
#  'Kim, So Youn(김소연)': Doctag(offset=70, word_count=2526, doc_count=1),
#  'An, Kwangjin(안광진)': Doctag(offset=71, word_count=5502, doc_count=1),
#  'Kang, Sang Hoon(강상훈)': Doctag(offset=72, word_count=2664, doc_count=1),
#  'Choi, Kyudong(최규동)': Doctag(offset=73, word_count=309, doc_count=1),
#  'Park, Hyeon Keo(박현거)': Doctag(offset=74, word_count=29013, doc_count=1),
#  'Baek, Woongki(백웅기)': Doctag(offset=75, word_count=3611, doc_count=1),
#  'Park, Jung-Hoon(박정훈)': Doctag(offset=76, word_count=1370, doc_count=1),
#  'Min, Kyung-Tai(민경태)': Doctag(offset=77, word_count=3113, doc_count=1),
#  'Bae, Hantaek(배한택)': Doctag(offset=78, word_count=846, doc_count=1),
#  'Shin, Hyeon Suk(신현석)': Doctag(offset=79, word_count=7088, doc_count=1),
#  'Shin, Hyung-Joon(신형준)': Doctag(offset=80, word_count=3811, doc_count=1),
#  'Jang, Ji-Hyun(장지현)': Doctag(offset=81, word_count=6951, doc_count=1),
#  'Kwon, Oh Hoon(권오훈)': Doctag(offset=82, word_count=6083, doc_count=1),
#  'Kim, Hyoil(김효일)': Doctag(offset=83, word_count=3324, doc_count=1),
#  'Oakley, Ian(OakleyIan)': Doctag(offset=84, word_count=8912, doc_count=1),
#  'Choi, Young Rok(최영록)': Doctag(offset=85, word_count=1037, doc_count=1),
#  'Kwon, H. Moo(권혁무)': Doctag(offset=86, word_count=13533, doc_count=1),
#  'Kwon, Soon-Yong(권순용)': Doctag(offset=87, word_count=7628, doc_count=1),
#  'Lee, Junghye(이정혜)': Doctag(offset=88, word_count=1054, doc_count=1),
#  'Fynan, Douglas A.(Douglas A. Fynan)': Doctag(offset=89, word_count=1093, doc_count=1),
#  'Choi, Kyoung Jin(최경진)': Doctag(offset=90, word_count=8767, doc_count=1),
#  'Kim, Guntae(김건태)': Doctag(offset=91, word_count=10826, doc_count=1),
#  'Jeong, Joonwoo(정준우)': Doctag(offset=92, word_count=1300, doc_count=1),
#  'Kwon, Oh-Sang(권오상)': Doctag(offset=93, word_count=1075, doc_count=1),
#  'Lee, Jaeseon(이재선)': Doctag(offset=94, word_count=2909, doc_count=1),
#  'Song, Myoung Hoon(송명훈)': Doctag(offset=95, word_count=5496, doc_count=1),
#  'Kim, Ju-Young(김주영)': Doctag(offset=96, word_count=10229, doc_count=1),
#  'Kim, Je-Hyung(김제형)': Doctag(offset=97, word_count=2888, doc_count=1),
#  'Moon, Jun(문준)': Doctag(offset=98, word_count=2507, doc_count=1),
#  'Jang, Bongsoo(장봉수)': Doctag(offset=99, word_count=2206, doc_count=1),
#  'Schultz, Thomas(SchultzThomas)': Doctag(offset=100, word_count=9696, doc_count=1),
#  'Sohn, Dong-Seong(손동성)': Doctag(offset=101, word_count=6954, doc_count=1),
#  'Mitchell, Robert J.(MitchellRobert James)': Doctag(offset=102, word_count=7488, doc_count=1),
#  'Cho, Gi-Hyoug(조기혁)': Doctag(offset=103, word_count=2832, doc_count=1),
#  'Kim, Byeong-Su(김병수)(2009-08~2018-09)': Doctag(offset=104, word_count=13079, doc_count=1),
#  'Choi, Nam-Soon(최남순)': Doctag(offset=105, word_count=10025, doc_count=1),
#  'Cho, Perter J.(조재현)': Doctag(offset=106, word_count=824, doc_count=1),
#  'Kim, Hee Reyoung(김희령)': Doctag(offset=107, word_count=6701, doc_count=1),
#  'Baig, Chunggi(백충기)': Doctag(offset=108, word_count=7752, doc_count=1),
#  'Kang, Seokhyeong(강석형)(2014-08~2018-03)': Doctag(offset=109, word_count=4178, doc_count=1),
#  'Lee, Jongeun(이종은)': Doctag(offset=110, word_count=7311, doc_count=1),
#  'Zhang, Lu(ZhangLu)': Doctag(offset=111, word_count=1365, doc_count=1),
#  'Kim, Sung Youb(김성엽)': Doctag(offset=112, word_count=6873, doc_count=1),
#  'Kim, Jin Young(김진영)': Doctag(offset=113, word_count=15705, doc_count=1),
#  'Woo, Hangyun(우한균)': Doctag(offset=114, word_count=726, doc_count=1),
#  'Lee, Ki-Suk(이기석)': Doctag(offset=115, word_count=6427, doc_count=1),
#  'Kwon, Daeil(권대일)': Doctag(offset=116, word_count=4439, doc_count=1),
#  'Lee, Semin(이세민)': Doctag(offset=117, word_count=4732, doc_count=1),
#  'Park, Hyung Wook(박형욱)': Doctag(offset=118, word_count=10232, doc_count=1),
#  'Lim, Sunghoon(임성훈)': Doctag(offset=119, word_count=867, doc_count=1),
#  'Seo, Yongwon(서용원)': Doctag(offset=120, word_count=7628, doc_count=1),
#  'Jun, Yubin(전유빈)': Doctag(offset=121, word_count=1968, doc_count=1),
#  'Byun, Gangil(변강일)': Doctag(offset=122, word_count=3643, doc_count=1),
#  'Kim, Chae Un(김채운)': Doctag(offset=123, word_count=321, doc_count=1),
#  'Lee, Yongjae(이용재)': Doctag(offset=124, word_count=434, doc_count=1),
#  'Kim, Kyung Rok(김경록)': Doctag(offset=125, word_count=4853, doc_count=1),
#  'Choi, Jang Hyun(최장현)': Doctag(offset=126, word_count=5544, doc_count=1),
#  'Lim, Chiehyeon(임치현)': Doctag(offset=127, word_count=2230, doc_count=1),
#  'Kim, Eunhee(김은희)': Doctag(offset=128, word_count=4840, doc_count=1),
#  'Kim, Molan(김모란)': Doctag(offset=129, word_count=456, doc_count=1),
#  'Kang, Sebyung(강세병)': Doctag(offset=130, word_count=6163, doc_count=1),
#  'Kim, Yeolib(김여립)': Doctag(offset=131, word_count=631, doc_count=1),
#  'Yang, Hyun Jong(양현종)': Doctag(offset=132, word_count=4519, doc_count=1),
#  'Amblard, Francois(AmblardFrancois)': Doctag(offset=133, word_count=4572, doc_count=1),
#  'Self, James(SelfJames Andrew)': Doctag(offset=134, word_count=1748, doc_count=1),
#  'Oh, Joo Hwan(오주환)': Doctag(offset=135, word_count=1924, doc_count=1),
#  'Byon, Chan(변찬)': Doctag(offset=136, word_count=11375, doc_count=1),
#  'Kim, Yunho(김윤호)': Doctag(offset=137, word_count=1120, doc_count=1),
#  'Park, Chan Young(박찬영)': Doctag(offset=138, word_count=2862, doc_count=1),
#  'Park, Jang-Ung(박장웅)(2010-08~2018-09)': Doctag(offset=139, word_count=6181, doc_count=1),
#  'Lee, Geunsik(이근식)': Doctag(offset=140, word_count=7836, doc_count=1),
#  'Park, Lee Soon(박이순)': Doctag(offset=141, word_count=15659, doc_count=1),
#  'Kim, Taesung(김태성)': Doctag(offset=142, word_count=9144, doc_count=1),
#  'Sun, Hae-sang(선해상)': Doctag(offset=143, word_count=169, doc_count=1),
#  'Chang, Jiwon(장지원)': Doctag(offset=144, word_count=1880, doc_count=1),
#  'Seok, Sang Il(석상일)': Doctag(offset=145, word_count=12945, doc_count=1),
#  'Nam, Beomseok(남범석)(2010-08~2018-03)': Doctag(offset=146, word_count=4232, doc_count=1),
#  'Kwon, Tae-Hyuk(권태혁)': Doctag(offset=147, word_count=3396, doc_count=1),
#  'Kang, Seok Ju(강석주)': Doctag(offset=148, word_count=6318, doc_count=1),
#  'Oh, Hyondong(오현동)': Doctag(offset=149, word_count=4797, doc_count=1),
#  'Lee, Jae Hwa(이재화)': Doctag(offset=150, word_count=6095, doc_count=1),
#  'Lee, Jacob C.(이채호)': Doctag(offset=151, word_count=363, doc_count=1),
#  'Choi, Jin Hyuk(최진혁)': Doctag(offset=152, word_count=223, doc_count=1),
#  'Son, Hungsun(손흥선)': Doctag(offset=153, word_count=5891, doc_count=1),
#  'Jang, Jaesung(장재성)': Doctag(offset=154, word_count=3091, doc_count=1),
#  'Ko, Sungahn(고성안)': Doctag(offset=155, word_count=1368, doc_count=1),
#  'Vigneron, Antoine(VigneronAntoine)': Doctag(offset=156, word_count=4021, doc_count=1),
#  'Shin, Heungjoo(신흥주)': Doctag(offset=157, word_count=6038, doc_count=1),
#  'Park, Jiyoung(박지영)': Doctag(offset=158, word_count=4211, doc_count=1),
#  'Torbol, Marco(TorbolMarco)': Doctag(offset=159, word_count=3995, doc_count=1),
#  'Bae, Joonbum(배준범)': Doctag(offset=160, word_count=9369, doc_count=1),
#  'Ki, Hyungson(기형선)': Doctag(offset=161, word_count=4873, doc_count=1),
#  'Kim, Gun-Ho(김건호)': Doctag(offset=162, word_count=921, doc_count=1),
#  'Kwon, Min-Suk(권민석)': Doctag(offset=163, word_count=3955, doc_count=1),
#  'Cha, Chaenyung(차채녕)': Doctag(offset=164, word_count=4971, doc_count=1),
#  'Kim, Jingook(김진국)': Doctag(offset=165, word_count=7595, doc_count=1),
#  'Lee, Ja Yil(이자일)': Doctag(offset=166, word_count=1610, doc_count=1),
#  'Lim, Hankwon(임한권)': Doctag(offset=167, word_count=5366, doc_count=1),
#  'Kim, Kwanpyo(김관표)(2014-05~2018-03)': Doctag(offset=168, word_count=4639, doc_count=1),
#  'Shin, GwanSeob(신관섭)': Doctag(offset=169, word_count=5389, doc_count=1),
#  'Kim, Jae Joon(김재준)': Doctag(offset=170, word_count=2801, doc_count=1),
#  'Yang, Seungjoon(양승준)': Doctag(offset=171, word_count=4214, doc_count=1),
#  'Seo, Kwanyong(서관용)': Doctag(offset=172, word_count=6624, doc_count=1),
#  'Kim, Jeong Beom(김정범)': Doctag(offset=173, word_count=2366, doc_count=1),
#  'Kim, Ji Hyun(김지현)': Doctag(offset=174, word_count=11423, doc_count=1),
#  'Hwang, Sung Ju(황성주)(2014-08~2018-01)': Doctag(offset=175, word_count=1953, doc_count=1),
#  'Lee, Kyuho Jason(이규호)': Doctag(offset=176, word_count=2896, doc_count=1),
#  'Lee, Jun Hee(이준희)': Doctag(offset=177, word_count=3383, doc_count=1),
#  'Jung, Chang-Yeol(정창렬)': Doctag(offset=178, word_count=3894, doc_count=1),
#  'Cho, Kyung Hwa(조경화)': Doctag(offset=179, word_count=10383, doc_count=1),
#  'Park, Kibog(박기복)': Doctag(offset=180, word_count=4216, doc_count=1),
#  'Yang, Changduk(양창덕)': Doctag(offset=181, word_count=13973, doc_count=1),
#  'Ryu, Ja-Hyoung(유자형)': Doctag(offset=182, word_count=5096, doc_count=1),
#  'Yoo, Jung-Woo(유정우)': Doctag(offset=183, word_count=4585, doc_count=1),
#  'Kim, Young Choon(김영춘)': Doctag(offset=184, word_count=941, doc_count=1),
#  'Yoon, Eisung(윤의성)': Doctag(offset=185, word_count=1182, doc_count=1),
#  'Kang, Joo H.(강주헌)': Doctag(offset=186, word_count=1416, doc_count=1),
#  'Bielawski, Christopher W.(BielawskiChristopher W)': Doctag(offset=187, word_count=25573, doc_count=1),
#  'Chung, Il-Sug(정일석)': Doctag(offset=188, word_count=4633, doc_count=1),
#  'Kim, Sungil(김성일)': Doctag(offset=189, word_count=1065, doc_count=1),
#  'Sim, Sung-Han(심성한)': Doctag(offset=190, word_count=9407, doc_count=1),
#  'Park, Young-Bin(박영빈)': Doctag(offset=191, word_count=13124, doc_count=1),
#  'Lee, Sung Kuk(이성국)': Doctag(offset=192, word_count=4989, doc_count=1),
#  'Park, Tae-Eun(박태은)': Doctag(offset=193, word_count=3112, doc_count=1),
#  'Bae, Sung Chul(배성철)': Doctag(offset=194, word_count=4560, doc_count=1),
#  'Jang, Ji-Wook(장지욱)': Doctag(offset=195, word_count=5175, doc_count=1),
#  'Jin, Hosub(진호섭)': Doctag(offset=196, word_count=3920, doc_count=1),
#  'Kim, Seong-Jin(김성진)': Doctag(offset=197, word_count=2260, doc_count=1),
#  'Chung, Jin-Ho(정진호)': Doctag(offset=198, word_count=2671, doc_count=1),
#  'Jung, Kooyul(정구열)': Doctag(offset=199, word_count=1540, doc_count=1),
#  'Kim, Jae-Ick(김재익)': Doctag(offset=200, word_count=1988, doc_count=1),
#  'Kim, Jiyun(김지윤)': Doctag(offset=201, word_count=1260, doc_count=1),
#  'Park, Jongnam(박종남)': Doctag(offset=202, word_count=6370, doc_count=1),
#  'Ryu, Dongsu(류동수)': Doctag(offset=203, word_count=23054, doc_count=1),
#  'Kim, Byungmin(김병민)': Doctag(offset=204, word_count=1339, doc_count=1),
#  'Jung, Woonggyu(정웅규)': Doctag(offset=205, word_count=11145, doc_count=1),
#  'Baek, Jong-Beom(백종범)': Doctag(offset=206, word_count=20400, doc_count=1),
#  'Grzybowski, Bartosz A.(GrzybowskiBartosz Andrzej)': Doctag(offset=207, word_count=20328, doc_count=1),
#  'Chung, Jibum(정지범)': Doctag(offset=208, word_count=893, doc_count=1),
#  'Cho, Yoon-Kyoung(조윤경)': Doctag(offset=209, word_count=11510, doc_count=1),
#  'Bang, In Cheol(방인철)': Doctag(offset=210, word_count=17706, doc_count=1),
#  'Kwak, Kyujin(곽규진)': Doctag(offset=211, word_count=2963, doc_count=1),
#  'Kim, Pilwon(김필원)': Doctag(offset=212, word_count=1631, doc_count=1),
#  'Kim, Jeongseob(김정섭)': Doctag(offset=213, word_count=1222, doc_count=1),
#  'Jeong, Hoon Eui(정훈의)': Doctag(offset=214, word_count=6646, doc_count=1),
#  'Kim, MinChung(김민중)': Doctag(offset=215, word_count=1010, doc_count=1),
#  'Park, Jaeyeong(박재영)': Doctag(offset=216, word_count=1012, doc_count=1),
#  'Cho, Jaephil(조재필)': Doctag(offset=217, word_count=28277, doc_count=1),
#  'Jeong, Won-Ki(정원기)': Doctag(offset=218, word_count=5462, doc_count=1),
#  'Kwon, Bongsuk(권봉석)': Doctag(offset=219, word_count=1624, doc_count=1),
#  'Au, Tsz-Chiu(AuTsz-Chiu)': Doctag(offset=220, word_count=1478, doc_count=1),
#  'Kwak, Ja Hun(곽자훈)': Doctag(offset=221, word_count=17591, doc_count=1),
#  'Kim, Katherine A.(김예린)': Doctag(offset=222, word_count=3792, doc_count=1),
#  'Kim, Hajin(김하진)': Doctag(offset=223, word_count=6583, doc_count=1),
#  'Lee, Chang Young(이창영)': Doctag(offset=224, word_count=8931, doc_count=1),
#  'Baik, Jeong Min(백정민)': Doctag(offset=225, word_count=8998, doc_count=1),
#  'Choe, Wonyoung(최원영)': Doctag(offset=226, word_count=3604, doc_count=1),
#  'Hong, Hwajung(홍화정)(2015-08~2018-03)': Doctag(offset=227, word_count=1780, doc_count=1),
#  'Kwon, Min Sang(권민상)': Doctag(offset=228, word_count=1976, doc_count=1),
#  'Kim, KwanMyung(김관명)': Doctag(offset=229, word_count=1551, doc_count=1),
#  'Song, Hyun-Kon(송현곤)': Doctag(offset=230, word_count=10331, doc_count=1),
#  'Park, Young-Woo(박영우)': Doctag(offset=231, word_count=782, doc_count=1),
#  'Kim, Yung Sam(김영삼)': Doctag(offset=232, word_count=2646, doc_count=1),
#  'Chung, Dongil(정동일)': Doctag(offset=233, word_count=1437, doc_count=1),
#  'Ji, Wooseok(지우석)': Doctag(offset=234, word_count=2653, doc_count=1),
#  'Kim, Namhun(김남훈)': Doctag(offset=235, word_count=5389, doc_count=1),
#  'Lee, Changsoo(이창수)': Doctag(offset=236, word_count=8883, doc_count=1),
#  'Park, Young S.(박영석)': Doctag(offset=237, word_count=1225, doc_count=1),
#  'Rohde, Jan-Uwe(RohdeJan-Uwe)': Doctag(offset=238, word_count=5021, doc_count=1),
#  'Lee, Jae Sung(이재성)': Doctag(offset=239, word_count=34083, doc_count=1),
#  'Lah, Myoung Soo(나명수)': Doctag(offset=240, word_count=11260, doc_count=1),
#  'Lee, Sang-Young(이상영)': Doctag(offset=241, word_count=13219, doc_count=1),
#  'Park, Hyesung(박혜성)': Doctag(offset=242, word_count=2059, doc_count=1),
#  'Moon, Hyungon(문현곤)': Doctag(offset=243, word_count=939, doc_count=1),
#  'Choi, EunMi(최은미)': Doctag(offset=244, word_count=5790, doc_count=1),
#  'Ghim, Cheol-Min(김철민)': Doctag(offset=245, word_count=2428, doc_count=1),
#  'In, Yongkyoon(인용균)': Doctag(offset=246, word_count=7674, doc_count=1),
#  'Kim, Kwang S.(김광수)': Doctag(offset=247, word_count=42203, doc_count=1),
#  'Chung, Moses(정모세)': Doctag(offset=248, word_count=3529, doc_count=1),
#  'Lim, Chunghun(임정훈)': Doctag(offset=249, word_count=3570, doc_count=1),
#  'Kim, Duck Young(김덕영)': Doctag(offset=250, word_count=1118, doc_count=1),
#  'Son, Jae Sung(손재성)': Doctag(offset=251, word_count=3129, doc_count=1),
#  'Jun, Young Chul(전영철)': Doctag(offset=252, word_count=3810, doc_count=1),
#  'Kang, Hyun-Wook(강현욱)': Doctag(offset=253, word_count=4725, doc_count=1),
#  'Hong, Sung You(홍성유)': Doctag(offset=254, word_count=3076, doc_count=1),
#  'Jo, Wook(조욱)': Doctag(offset=255, word_count=13482, doc_count=1),
#  'Joo, Sang Hoon(주상훈)': Doctag(offset=256, word_count=13872, doc_count=1),
#  'Lee, Jiseok(이지석)': Doctag(offset=257, word_count=1867, doc_count=1),
#  'comparative': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c550>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c588>,
#  'vera': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c5c0>,
#  'depletion': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c5f8>,
#  'benchmark': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c630>,
#  'consistent': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c668>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c6a0>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c6d8>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c710>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c748>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c780>,
#  'neutronics': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c7b8>,
#  'optimization': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c7f0>,
#  'calculation': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c828>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c860>,
#  'performed': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c898>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c8d0>,
#  'sensitivity': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c908>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c940>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c978>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c9b0>,
#  'transmutation': <gensim.models.keyedvectors.Vocab at 0x1a2ac0c9e8>,
#  'equation': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ca20>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ca58>,
#  'numerical': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ca90>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cac8>,
#  'mesh': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cb00>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cb38>,
#  'burnup': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cb70>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cba8>,
#  'recoverable': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cbe0>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cc18>,
#  'fission': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cc50>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cc88>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ccc0>,
#  'successfully': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ccf8>,
#  'demonstrated': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cd30>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cd68>,
#  'consistency': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cda0>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cdd8>,
#  'mitigate': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ce10>,
#  'adverse': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ce48>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ce80>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1a2ac0ceb8>,
#  'kappa': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cef0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cf28>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cf60>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cf98>,
#  '148nd': <gensim.models.keyedvectors.Vocab at 0x1a2ac0cfd0>,
#  'cumulative': <gensim.models.keyedvectors.Vocab at 0x1a2ac20048>,
#  'flux': <gensim.models.keyedvectors.Vocab at 0x1a2ac20080>,
#  'indicator': <gensim.models.keyedvectors.Vocab at 0x1a2ac200b8>,
#  'intra': <gensim.models.keyedvectors.Vocab at 0x1a2ac200f0>,
#  'zone': <gensim.models.keyedvectors.Vocab at 0x1a2ac20128>,
#  'suite': <gensim.models.keyedvectors.Vocab at 0x1a2ac20160>,
#  'verification': <gensim.models.keyedvectors.Vocab at 0x1a2ac20198>,
#  'validation': <gensim.models.keyedvectors.Vocab at 0x1a2ac201d0>,
#  'radiation': <gensim.models.keyedvectors.Vocab at 0x1a2ac20208>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x1a2ac20240>,
#  'capability': <gensim.models.keyedvectors.Vocab at 0x1a2ac20278>,
#  'stream': <gensim.models.keyedvectors.Vocab at 0x1a2ac202b0>,
#  'implemented': <gensim.models.keyedvectors.Vocab at 0x1a2ac202e8>,
#  'reactor': <gensim.models.keyedvectors.Vocab at 0x1a2ac20320>,
#  'pressurized': <gensim.models.keyedvectors.Vocab at 0x1a2ac20358>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1a2ac20390>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1a2ac203c8>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x1a2ac20400>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x1a2ac20438>,
#  'decay': <gensim.models.keyedvectors.Vocab at 0x1a2ac20470>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1a2ac204a8>,
#  'neutron': <gensim.models.keyedvectors.Vocab at 0x1a2ac204e0>,
#  'gamma': <gensim.models.keyedvectors.Vocab at 0x1a2ac20518>,
#  'spectrum': <gensim.models.keyedvectors.Vocab at 0x1a2ac20550>,
#  'irradiated': <gensim.models.keyedvectors.Vocab at 0x1a2ac20588>,
#  'assembly': <gensim.models.keyedvectors.Vocab at 0x1a2ac205c0>,
#  'calculated': <gensim.models.keyedvectors.Vocab at 0x1a2ac205f8>,
#  'origen': <gensim.models.keyedvectors.Vocab at 0x1a2ac20630>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x1a2ac20668>,
#  'obtained': <gensim.models.keyedvectors.Vocab at 0x1a2ac206a0>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x1a2ac206d8>,
#  'westinghouse': <gensim.models.keyedvectors.Vocab at 0x1a2ac20710>,
#  'combustion': <gensim.models.keyedvectors.Vocab at 0x1a2ac20748>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x1a2ac20780>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1a2ac207b8>,
#  'enrichment': <gensim.models.keyedvectors.Vocab at 0x1a2ac207f0>,
#  '235u': <gensim.models.keyedvectors.Vocab at 0x1a2ac20828>,
#  'cooling': <gensim.models.keyedvectors.Vocab at 0x1a2ac20860>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a2ac20898>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a2ac208d0>,
#  'indicates': <gensim.models.keyedvectors.Vocab at 0x1a2ac20908>,
#  'implementation': <gensim.models.keyedvectors.Vocab at 0x1a2ac20940>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x1a2ac20978>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1a2ac209b0>,
#  'comparing': <gensim.models.keyedvectors.Vocab at 0x1a2ac209e8>,
#  'calorimetric': <gensim.models.keyedvectors.Vocab at 0x1a2ac20a20>,
#  'measurement': <gensim.models.keyedvectors.Vocab at 0x1a2ac20a58>,
#  'swedish': <gensim.models.keyedvectors.Vocab at 0x1a2ac20a90>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x1a2ac20ac8>,
#  'storage': <gensim.models.keyedvectors.Vocab at 0x1a2ac20b00>,
#  'facility': <gensim.models.keyedvectors.Vocab at 0x1a2ac20b38>,
#  'clab': <gensim.models.keyedvectors.Vocab at 0x1a2ac20b70>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x1a2ac20ba8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1a2ac20be0>,
#  'hanford': <gensim.models.keyedvectors.Vocab at 0x1a2ac20c18>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x1a2ac20c50>,
#  'laboratory': <gensim.models.keyedvectors.Vocab at 0x1a2ac20c88>,
#  'hedl': <gensim.models.keyedvectors.Vocab at 0x1a2ac20cc0>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x1a2ac20cf8>,
#  'electric': <gensim.models.keyedvectors.Vocab at 0x1a2ac20d30>,
#  'morris': <gensim.models.keyedvectors.Vocab at 0x1a2ac20d68>,
#  'operation': <gensim.models.keyedvectors.Vocab at 0x1a2ac20da0>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x1a2ac20dd8>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1a2ac20e10>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1a2ac20e48>,
#  'agreement': <gensim.models.keyedvectors.Vocab at 0x1a2ac20e80>,
#  'analyzed': <gensim.models.keyedvectors.Vocab at 0x1a2ac20eb8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1a2ac20ef0>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x1a2ac20f28>,
#  'uncertainty': <gensim.models.keyedvectors.Vocab at 0x1a2ac20f60>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x1a2ac20f98>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x1a2ac20fd0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a2ac23048>,
#  'demonstrates': <gensim.models.keyedvectors.Vocab at 0x1a2ac23080>,
#  'reliably': <gensim.models.keyedvectors.Vocab at 0x1a2ac230b8>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1a2ac230f0>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x1a2ac23128>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x1a2ac23160>,
#  'lattice': <gensim.models.keyedvectors.Vocab at 0x1a2ac23198>,
#  'simplification': <gensim.models.keyedvectors.Vocab at 0x1a2ac231d0>,
#  'unist': <gensim.models.keyedvectors.Vocab at 0x1a2ac23208>,
#  'steady': <gensim.models.keyedvectors.Vocab at 0x1a2ac23240>,
#  'transient': <gensim.models.keyedvectors.Vocab at 0x1a2ac23278>,
#  'characteristic': <gensim.models.keyedvectors.Vocab at 0x1a2ac232b0>,
#  'alleviate': <gensim.models.keyedvectors.Vocab at 0x1a2ac232e8>,
#  'computational': <gensim.models.keyedvectors.Vocab at 0x1a2ac23320>,
#  'burden': <gensim.models.keyedvectors.Vocab at 0x1a2ac23358>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x1a2ac23390>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x1a2ac233c8>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x1a2ac23400>,
#  'simplified': <gensim.models.keyedvectors.Vocab at 0x1a2ac23438>,
#  'nuclides': <gensim.models.keyedvectors.Vocab at 0x1a2ac23470>,
#  'transition': <gensim.models.keyedvectors.Vocab at 0x1a2ac234a8>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x1a2ac234e0>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x1a2ac23518>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x1a2ac23550>,
#  'containing': <gensim.models.keyedvectors.Vocab at 0x1a2ac23588>,
#  'endf': <gensim.models.keyedvectors.Vocab at 0x1a2ac235c0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1a2ac235f8>,
#  'optimized': <gensim.models.keyedvectors.Vocab at 0x1a2ac23630>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x1a2ac23668>,
#  'calculating': <gensim.models.keyedvectors.Vocab at 0x1a2ac236a0>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x1a2ac236d8>,
#  'multiplication': <gensim.models.keyedvectors.Vocab at 0x1a2ac23710>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x1a2ac23748>,
#  'keff': <gensim.models.keyedvectors.Vocab at 0x1a2ac23780>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x1a2ac237b8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x1a2ac237f0>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x1a2ac23828>,
#  'computation': <gensim.models.keyedvectors.Vocab at 0x1a2ac23860>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x1a2ac23898>,
#  'usage': <gensim.models.keyedvectors.Vocab at 0x1a2ac238d0>,
#  'nuclide': <gensim.models.keyedvectors.Vocab at 0x1a2ac23908>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x1a2ac23940>,
#  'relies': <gensim.models.keyedvectors.Vocab at 0x1a2ac23978>,
#  'generalized': <gensim.models.keyedvectors.Vocab at 0x1a2ac239b0>,
#  'perturbation': <gensim.models.keyedvectors.Vocab at 0x1a2ac239e8>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x1a2ac23a20>,
#  'exploiting': <gensim.models.keyedvectors.Vocab at 0x1a2ac23a58>,
#  'adjoint': <gensim.models.keyedvectors.Vocab at 0x1a2ac23a90>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x1a2ac23ac8>,
#  'derived': <gensim.models.keyedvectors.Vocab at 0x1a2ac23b00>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1a2ac23b38>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x1a2ac23b70>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x1a2ac23ba8>,
#  'contribution': <gensim.models.keyedvectors.Vocab at 0x1a2ac23be0>,
#  'reactivity': <gensim.models.keyedvectors.Vocab at 0x1a2ac23c18>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x1a2ac23c50>,
#  'conducted': <gensim.models.keyedvectors.Vocab at 0x1a2ac23c88>,
#  'deterministic': <gensim.models.keyedvectors.Vocab at 0x1a2ac23cc0>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x1a2ac23cf8>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x1a2ac23d30>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x1a2ac23d68>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1a2ac23da0>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x1a2ac23dd8>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x1a2ac23e10>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1a2ac23e48>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x1a2ac23e80>,
#  'tested': <gensim.models.keyedvectors.Vocab at 0x1a2ac23eb8>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x1a2ac23ef0>,
#  'virtual': <gensim.models.keyedvectors.Vocab at 0x1a2ac23f28>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x1a2ac23f60>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x1a2ac23f98>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1a2ac23fd0>,
#  'burnable': <gensim.models.keyedvectors.Vocab at 0x1a2ac25048>,
#  'poison': <gensim.models.keyedvectors.Vocab at 0x1a2ac25080>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x1a2ac250b8>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x1a2ac250f0>,
#  'gadolinia': <gensim.models.keyedvectors.Vocab at 0x1a2ac25128>,
#  'pyrex': <gensim.models.keyedvectors.Vocab at 0x1a2ac25160>,
#  'ifba': <gensim.models.keyedvectors.Vocab at 0x1a2ac25198>,
#  'gadolinium': <gensim.models.keyedvectors.Vocab at 0x1a2ac251d0>,
#  'bearing': <gensim.models.keyedvectors.Vocab at 0x1a2ac25208>,
#  'ranging': <gensim.models.keyedvectors.Vocab at 0x1a2ac25240>,
#  'variation': <gensim.models.keyedvectors.Vocab at 0x1a2ac25278>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x1a2ac252b0>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x1a2ac252e8>,
#  'reduction': <gensim.models.keyedvectors.Vocab at 0x1a2ac25320>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x1a2ac25358>,
#  'simulation': <gensim.models.keyedvectors.Vocab at 0x1a2ac25390>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1a2ac253c8>,
#  'elsevier': <gensim.models.keyedvectors.Vocab at 0x1a2ac25400>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1a2ac25438>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x1a2ac25470>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1a2ac254a8>,
#  'modular': <gensim.models.keyedvectors.Vocab at 0x1a2ac254e0>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1a2ac25518>,
#  'cooled': <gensim.models.keyedvectors.Vocab at 0x1a2ac25550>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1a2ac25588>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x1a2ac255c0>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x1a2ac255f8>,
#  'smlfr': <gensim.models.keyedvectors.Vocab at 0x1a2ac25630>,
#  'bismuth': <gensim.models.keyedvectors.Vocab at 0x1a2ac25668>,
#  'eutectic': <gensim.models.keyedvectors.Vocab at 0x1a2ac256a0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1a2ac256d8>,
#  'constraint': <gensim.models.keyedvectors.Vocab at 0x1a2ac25710>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1a2ac25748>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x1a2ac25780>,
#  'transported': <gensim.models.keyedvectors.Vocab at 0x1a2ac257b8>,
#  'cask': <gensim.models.keyedvectors.Vocab at 0x1a2ac257f0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1a2ac25828>,
#  'electricity': <gensim.models.keyedvectors.Vocab at 0x1a2ac25860>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x1a2ac25898>,
#  'remote': <gensim.models.keyedvectors.Vocab at 0x1a2ac258d0>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1a2ac25908>,
#  'grid': <gensim.models.keyedvectors.Vocab at 0x1a2ac25940>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x1a2ac25978>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x1a2ac259b0>,
#  'icebreaker': <gensim.models.keyedvectors.Vocab at 0x1a2ac259e8>,
#  'ship': <gensim.models.keyedvectors.Vocab at 0x1a2ac25a20>,
#  'satisfy': <gensim.models.keyedvectors.Vocab at 0x1a2ac25a58>,
#  'requirement': <gensim.models.keyedvectors.Vocab at 0x1a2ac25a90>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1a2ac25ac8>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x1a2ac25b00>,
#  'diameter': <gensim.models.keyedvectors.Vocab at 0x1a2ac25b38>,
#  'fueled': <gensim.models.keyedvectors.Vocab at 0x1a2ac25b70>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x1a2ac25ba8>,
#  'enriched': <gensim.models.keyedvectors.Vocab at 0x1a2ac25be0>,
#  'uranium': <gensim.models.keyedvectors.Vocab at 0x1a2ac25c18>,
#  'nitride': <gensim.models.keyedvectors.Vocab at 0x1a2ac25c50>,
#  'designed': <gensim.models.keyedvectors.Vocab at 0x1a2ac25c88>,
#  'achieve': <gensim.models.keyedvectors.Vocab at 0x1a2ac25cc0>,
#  'thermal': <gensim.models.keyedvectors.Vocab at 0x1a2ac25cf8>,
#  'assumption': <gensim.models.keyedvectors.Vocab at 0x1a2ac25d30>,
#  'efficiency': <gensim.models.keyedvectors.Vocab at 0x1a2ac25d68>,
#  'employing': <gensim.models.keyedvectors.Vocab at 0x1a2ac25da0>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x1a2ac25dd8>,
#  'conversion': <gensim.models.keyedvectors.Vocab at 0x1a2ac25e10>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1a2ac25e48>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x1a2ac25e80>,
#  'supercritical': <gensim.models.keyedvectors.Vocab at 0x1a2ac25eb8>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x1a2ac25ef0>,
#  'dioxide': <gensim.models.keyedvectors.Vocab at 0x1a2ac25f28>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x1a2ac25f60>,
#  'fluid': <gensim.models.keyedvectors.Vocab at 0x1a2ac25f98>,
#  'brayton': <gensim.models.keyedvectors.Vocab at 0x1a2ac25fd0>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x1a2ac29048>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x1a2ac29080>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x1a2ac290b8>,
#  'rankine': <gensim.models.keyedvectors.Vocab at 0x1a2ac290f0>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x1a2ac29128>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x1a2ac29160>,
#  'performs': <gensim.models.keyedvectors.Vocab at 0x1a2ac29198>,
#  'ignition': <gensim.models.keyedvectors.Vocab at 0x1a2ac291d0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1a2ac29208>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1a2ac29240>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x1a2ac29278>,
#  'breeding': <gensim.models.keyedvectors.Vocab at 0x1a2ac292b0>,
#  'blanket': <gensim.models.keyedvectors.Vocab at 0x1a2ac292e8>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x1a2ac29320>,
#  'lifetime': <gensim.models.keyedvectors.Vocab at 0x1a2ac29358>,
#  'inlet': <gensim.models.keyedvectors.Vocab at 0x1a2ac29390>,
#  'outlet': <gensim.models.keyedvectors.Vocab at 0x1a2ac293c8>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x1a2ac29400>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x1a2ac29438>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x1a2ac29470>,
#  'coolant': <gensim.models.keyedvectors.Vocab at 0x1a2ac294a8>,
#  'circulation': <gensim.models.keyedvectors.Vocab at 0x1a2ac294e0>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x1a2ac29518>,
#  'electromagnetic': <gensim.models.keyedvectors.Vocab at 0x1a2ac29550>,
#  'pump': <gensim.models.keyedvectors.Vocab at 0x1a2ac29588>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x1a2ac295c0>,
#  'isotopic': <gensim.models.keyedvectors.Vocab at 0x1a2ac295f8>,
#  'inventory': <gensim.models.keyedvectors.Vocab at 0x1a2ac29630>,
#  'criticality': <gensim.models.keyedvectors.Vocab at 0x1a2ac29668>,
#  'radial': <gensim.models.keyedvectors.Vocab at 0x1a2ac296a0>,
#  'axial': <gensim.models.keyedvectors.Vocab at 0x1a2ac296d8>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x1a2ac29710>,
#  'shutdown': <gensim.models.keyedvectors.Vocab at 0x1a2ac29748>,
#  'margin': <gensim.models.keyedvectors.Vocab at 0x1a2ac29780>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x1a2ac297b8>,
#  'coefficient': <gensim.models.keyedvectors.Vocab at 0x1a2ac297f0>,
#  'integral': <gensim.models.keyedvectors.Vocab at 0x1a2ac29828>,
#  'parameter': <gensim.models.keyedvectors.Vocab at 0x1a2ac29860>,
#  'quasi': <gensim.models.keyedvectors.Vocab at 0x1a2ac29898>,
#  'static': <gensim.models.keyedvectors.Vocab at 0x1a2ac298d0>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x1a2ac29908>,
#  'confirmed': <gensim.models.keyedvectors.Vocab at 0x1a2ac29940>,
#  'argonne': <gensim.models.keyedvectors.Vocab at 0x1a2ac29978>,
#  'operated': <gensim.models.keyedvectors.Vocab at 0x1a2ac299b0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1a2ac299e8>,
#  'refueling': <gensim.models.keyedvectors.Vocab at 0x1a2ac29a20>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x1a2ac29a58>,
#  'hydraulic': <gensim.models.keyedvectors.Vocab at 0x1a2ac29a90>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x1a2ac29ac8>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a2ac29b00>,
#  'confirms': <gensim.models.keyedvectors.Vocab at 0x1a2ac29b38>,
#  'cladding': <gensim.models.keyedvectors.Vocab at 0x1a2ac29b70>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x1a2ac29ba8>,
#  'monte': <gensim.models.keyedvectors.Vocab at 0x1a2ac29be0>,
#  'carlo': <gensim.models.keyedvectors.Vocab at 0x1a2ac29c18>,
#  'conceptual': <gensim.models.keyedvectors.Vocab at 0x1a2ac29c50>,
#  'favorable': <gensim.models.keyedvectors.Vocab at 0x1a2ac29c88>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x1a2ac29cc0>,
#  'controllability': <gensim.models.keyedvectors.Vocab at 0x1a2ac29cf8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1a2ac29d30>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x1a2ac29d68>,
#  'inherent': <gensim.models.keyedvectors.Vocab at 0x1a2ac29da0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1a2ac29dd8>,
#  'wiley': <gensim.models.keyedvectors.Vocab at 0x1a2ac29e10>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x1a2ac29e48>,
#  'evaluation': <gensim.models.keyedvectors.Vocab at 0x1a2ac29e80>,
#  'cmfd': <gensim.models.keyedvectors.Vocab at 0x1a2ac29eb8>,
#  'inter': <gensim.models.keyedvectors.Vocab at 0x1a2ac29ef0>,
#  'correlation': <gensim.models.keyedvectors.Vocab at 0x1a2ac29f28>,
#  'examination': <gensim.models.keyedvectors.Vocab at 0x1a2ac29f60>,
#  'coarse': <gensim.models.keyedvectors.Vocab at 0x1a2ac29f98>,
#  'finite': <gensim.models.keyedvectors.Vocab at 0x1a2ac29fd0>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d048>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d080>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d0b8>,
#  'reveal': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d0f0>,
#  'effectiveness': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d128>,
#  'depending': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d160>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d198>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d1d0>,
#  'section': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d208>,
#  'dependency': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d240>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d278>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d2b0>,
#  'continuous': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d2e8>,
#  'applying': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d320>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d358>,
#  'dimensional': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d390>,
#  'beavrs': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d3c8>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d400>,
#  'practical': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d438>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d470>,
#  'dominance': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d4a8>,
#  'ratio': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d4e0>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d518>,
#  'merit': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d550>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d588>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d5c0>,
#  'propagation': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d5f8>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d630>,
#  'npmm': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d668>,
#  'extended': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d6a0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d6d8>,
#  'compute': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d710>,
#  'essentially': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d748>,
#  'projection': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d780>,
#  'cmpm': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d7b8>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d7f0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d828>,
#  'finishing': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d860>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d898>,
#  'fundamental': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d8d0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d908>,
#  'explicitly': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d940>,
#  'utilized': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d978>,
#  'implicitly': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d9b0>,
#  'contained': <gensim.models.keyedvectors.Vocab at 0x1a2ac2d9e8>,
#  'statistical': <gensim.models.keyedvectors.Vocab at 0x1a2ac2da20>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x1a2ac2da58>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1a2ac2da90>,
#  'approximate': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dac8>,
#  'estimation': <gensim.models.keyedvectors.Vocab at 0x1a2ac2db00>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x1a2ac2db38>,
#  'simulating': <gensim.models.keyedvectors.Vocab at 0x1a2ac2db70>,
#  'accurate': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dba8>,
#  'efficient': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dbe0>,
#  'besides': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dc18>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dc50>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dc88>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dcc0>,
#  'unstable': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dcf8>,
#  'requested': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dd30>,
#  'eigenmodes': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dd68>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dda0>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x1a2ac2ddd8>,
#  'dependent': <gensim.models.keyedvectors.Vocab at 0x1a2ac2de10>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x1a2ac2de48>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x1a2ac2de80>,
#  'instability': <gensim.models.keyedvectors.Vocab at 0x1a2ac2deb8>,
#  'identified': <gensim.models.keyedvectors.Vocab at 0x1a2ac2def0>,
#  'degeneracy': <gensim.models.keyedvectors.Vocab at 0x1a2ac2df28>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x1a2ac2df60>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1a2ac2df98>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x1a2ac2dfd0>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x1a2ac30048>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x1a2ac30080>,
#  'accordingly': <gensim.models.keyedvectors.Vocab at 0x1a2ac300b8>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1a2ac300f0>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x1a2ac30128>,
#  'stability': <gensim.models.keyedvectors.Vocab at 0x1a2ac30160>,
#  'diffusion': <gensim.models.keyedvectors.Vocab at 0x1a2ac30198>,
#  'eigenvalue': <gensim.models.keyedvectors.Vocab at 0x1a2ac301d0>,
#  'c5g7': <gensim.models.keyedvectors.Vocab at 0x1a2ac30208>,
#  'resonance': <gensim.models.keyedvectors.Vocab at 0x1a2ac30240>,
#  'shielding': <gensim.models.keyedvectors.Vocab at 0x1a2ac30278>,
#  'interference': <gensim.models.keyedvectors.Vocab at 0x1a2ac302b0>,
#  'library': <gensim.models.keyedvectors.Vocab at 0x1a2ac302e8>,
#  'physic': <gensim.models.keyedvectors.Vocab at 0x1a2ac30320>,
#  'lwrs': <gensim.models.keyedvectors.Vocab at 0x1a2ac30358>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x1a2ac30390>,
#  'fidelity': <gensim.models.keyedvectors.Vocab at 0x1a2ac303c8>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1a2ac30400>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x1a2ac30438>,
#  'improvement': <gensim.models.keyedvectors.Vocab at 0x1a2ac30470>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1a2ac304a8>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x1a2ac304e0>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x1a2ac30518>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a2ac30550>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x1a2ac30588>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x1a2ac305c0>,
#  'prediction': <gensim.models.keyedvectors.Vocab at 0x1a2ac305f8>,
#  'newly': <gensim.models.keyedvectors.Vocab at 0x1a2ac30630>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x1a2ac30668>,
#  'quantified': <gensim.models.keyedvectors.Vocab at 0x1a2ac306a0>,
#  'tabulated': <gensim.models.keyedvectors.Vocab at 0x1a2ac306d8>,
#  'adjustment': <gensim.models.keyedvectors.Vocab at 0x1a2ac30710>,
#  'mosteller': <gensim.models.keyedvectors.Vocab at 0x1a2ac30748>,
#  'loaded': <gensim.models.keyedvectors.Vocab at 0x1a2ac30780>,
#  'atomic': <gensim.models.keyedvectors.Vocab at 0x1a2ac307b8>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x1a2ac307f0>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x1a2ac30828>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1a2ac30860>,
# ...
#  'intrinsic': <gensim.models.keyedvectors.Vocab at 0x1a2ac33390>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x1a2ac333c8>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1a2ac33400>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x1a2ac33438>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x1a2ac33470>,
#  'actinide': <gensim.models.keyedvectors.Vocab at 0x1a2ac334a8>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x1a2ac334e0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x1a2ac33518>,
#  'generate': <gensim.models.keyedvectors.Vocab at 0x1a2ac33550>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x1a2ac33588>,
#  'kurri': <gensim.models.keyedvectors.Vocab at 0x1a2ac335c0>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x1a2ac335f8>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x1a2ac33630>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x1a2ac33668>,
#  'cockcroft': <gensim.models.keyedvectors.Vocab at 0x1a2ac336a0>,
#  'walton': <gensim.models.keyedvectors.Vocab at 0x1a2ac336d8>,
#  'generates': <gensim.models.keyedvectors.Vocab at 0x1a2ac33710>,
#  'deuterium': <gensim.models.keyedvectors.Vocab at 0x1a2ac33748>,
#  'tritium': <gensim.models.keyedvectors.Vocab at 0x1a2ac33780>,
#  'neutronic': <gensim.models.keyedvectors.Vocab at 0x1a2ac337b8>,
#  'estimated': <gensim.models.keyedvectors.Vocab at 0x1a2ac337f0>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x1a2ac33828>,
#  'feasibility': <gensim.models.keyedvectors.Vocab at 0x1a2ac33860>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x1a2ac33898>,
#  'korea': <gensim.models.keyedvectors.Vocab at 0x1a2ac338d0>,
#  'behalf': <gensim.models.keyedvectors.Vocab at 0x1a2ac33908>,
#  'korean': <gensim.models.keyedvectors.Vocab at 0x1a2ac33940>,
#  'collective': <gensim.models.keyedvectors.Vocab at 0x1a2ac33978>,
#  'scattering': <gensim.models.keyedvectors.Vocab at 0x1a2ac339b0>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x1a2ac339e8>,
#  'turbulence': <gensim.models.keyedvectors.Vocab at 0x1a2ac33a20>,
#  'superconducting': <gensim.models.keyedvectors.Vocab at 0x1a2ac33a58>,
#  'tokamak': <gensim.models.keyedvectors.Vocab at 0x1a2ac33a90>,
#  'channel': <gensim.models.keyedvectors.Vocab at 0x1a2ac33ac8>,
#  'coherent': <gensim.models.keyedvectors.Vocab at 0x1a2ac33b00>,
#  'kstar': <gensim.models.keyedvectors.Vocab at 0x1a2ac33b38>,
#  'planned': <gensim.models.keyedvectors.Vocab at 0x1a2ac33b70>,
#  'installed': <gensim.models.keyedvectors.Vocab at 0x1a2ac33ba8>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1a2ac33be0>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x1a2ac33c18>,
#  'discussed': <gensim.models.keyedvectors.Vocab at 0x1a2ac33c50>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1a2ac33c88>,
#  'faraday': <gensim.models.keyedvectors.Vocab at 0x1a2ac33cc0>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x1a2ac33cf8>,
#  'mouton': <gensim.models.keyedvectors.Vocab at 0x1a2ac33d30>,
#  'beam': <gensim.models.keyedvectors.Vocab at 0x1a2ac33d68>,
#  'polarization': <gensim.models.keyedvectors.Vocab at 0x1a2ac33da0>,
#  'spatial': <gensim.models.keyedvectors.Vocab at 0x1a2ac33dd8>,
#  'resolution': <gensim.models.keyedvectors.Vocab at 0x1a2ac33e10>,
#  'probe': <gensim.models.keyedvectors.Vocab at 0x1a2ac33e48>,
#  'frequency': <gensim.models.keyedvectors.Vocab at 0x1a2ac33e80>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x1a2ac33eb8>,
#  'feasible': <gensim.models.keyedvectors.Vocab at 0x1a2ac33ef0>,
#  'optic': <gensim.models.keyedvectors.Vocab at 0x1a2ac33f28>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x1a2ac33f60>,
#  'simultaneous': <gensim.models.keyedvectors.Vocab at 0x1a2ac33f98>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x1a2ac33fd0>,
#  'fluctuation': <gensim.models.keyedvectors.Vocab at 0x1a2ac37048>,
#  'discrete': <gensim.models.keyedvectors.Vocab at 0x1a2ac37080>,
#  'poloidal': <gensim.models.keyedvectors.Vocab at 0x1a2ac370b8>,
#  'wavenumbers': <gensim.models.keyedvectors.Vocab at 0x1a2ac370f0>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x1a2ac37128>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x1a2ac37160>,
#  'corresponds': <gensim.models.keyedvectors.Vocab at 0x1a2ac37198>,
#  'normalized': <gensim.models.keyedvectors.Vocab at 0x1a2ac371d0>,
#  'wavenumber': <gensim.models.keyedvectors.Vocab at 0x1a2ac37208>,
#  'kθρe': <gensim.models.keyedvectors.Vocab at 0x1a2ac37240>,
#  'nominal': <gensim.models.keyedvectors.Vocab at 0x1a2ac37278>,
#  'plasma': <gensim.models.keyedvectors.Vocab at 0x1a2ac372b0>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x1a2ac372e8>,
#  'scattered': <gensim.models.keyedvectors.Vocab at 0x1a2ac37320>,
#  'extract': <gensim.models.keyedvectors.Vocab at 0x1a2ac37358>,
#  'phase': <gensim.models.keyedvectors.Vocab at 0x1a2ac37390>,
#  'quadrature': <gensim.models.keyedvectors.Vocab at 0x1a2ac373c8>,
#  'detection': <gensim.models.keyedvectors.Vocab at 0x1a2ac37400>,
#  'consisting': <gensim.models.keyedvectors.Vocab at 0x1a2ac37438>,
#  'antenna': <gensim.models.keyedvectors.Vocab at 0x1a2ac37470>,
#  'detector': <gensim.models.keyedvectors.Vocab at 0x1a2ac374a8>,
#  'array': <gensim.models.keyedvectors.Vocab at 0x1a2ac374e0>,
#  'electronics': <gensim.models.keyedvectors.Vocab at 0x1a2ac37518>,
#  'employed': <gensim.models.keyedvectors.Vocab at 0x1a2ac37550>,
#  'publishing': <gensim.models.keyedvectors.Vocab at 0x1a2ac37588>,
#  'absorber': <gensim.models.keyedvectors.Vocab at 0x1a2ac375c0>,
#  'boron': <gensim.models.keyedvectors.Vocab at 0x1a2ac375f8>,
#  'pwr': <gensim.models.keyedvectors.Vocab at 0x1a2ac37630>,
#  'aiming': <gensim.models.keyedvectors.Vocab at 0x1a2ac37668>,
#  'soluble': <gensim.models.keyedvectors.Vocab at 0x1a2ac376a0>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x1a2ac376d8>,
#  '157gd2o3': <gensim.models.keyedvectors.Vocab at 0x1a2ac37710>,
#  'covered': <gensim.models.keyedvectors.Vocab at 0x1a2ac37748>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x1a2ac37780>,
#  'layer': <gensim.models.keyedvectors.Vocab at 0x1a2ac377b8>,
#  'zr167er2': <gensim.models.keyedvectors.Vocab at 0x1a2ac377f0>,
#  'isotope': <gensim.models.keyedvectors.Vocab at 0x1a2ac37828>,
#  '157gd': <gensim.models.keyedvectors.Vocab at 0x1a2ac37860>,
#  '167er': <gensim.models.keyedvectors.Vocab at 0x1a2ac37898>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1a2ac378d0>,
#  'absorption': <gensim.models.keyedvectors.Vocab at 0x1a2ac37908>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x1a2ac37940>,
#  'fraction': <gensim.models.keyedvectors.Vocab at 0x1a2ac37978>,
#  'gd2o3': <gensim.models.keyedvectors.Vocab at 0x1a2ac379b0>,
#  'rod': <gensim.models.keyedvectors.Vocab at 0x1a2ac379e8>,
#  'conductivity': <gensim.models.keyedvectors.Vocab at 0x1a2ac37a20>,
#  'transmutes': <gensim.models.keyedvectors.Vocab at 0x1a2ac37a58>,
#  '158gd': <gensim.models.keyedvectors.Vocab at 0x1a2ac37a90>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x1a2ac37ac8>,
#  'residual': <gensim.models.keyedvectors.Vocab at 0x1a2ac37b00>,
#  'penalty': <gensim.models.keyedvectors.Vocab at 0x1a2ac37b38>,
#  'decrease': <gensim.models.keyedvectors.Vocab at 0x1a2ac37b70>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1a2ac37ba8>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x1a2ac37be0>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x1a2ac37c18>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1a2ac37c50>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x1a2ac37c88>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x1a2ac37cc0>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a2ac37cf8>,
#  'zircaloy': <gensim.models.keyedvectors.Vocab at 0x1a2ac37d30>,
#  'reflector': <gensim.models.keyedvectors.Vocab at 0x1a2ac37d68>,
#  'zirconium': <gensim.models.keyedvectors.Vocab at 0x1a2ac37da0>,
#  'existing': <gensim.models.keyedvectors.Vocab at 0x1a2ac37dd8>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x1a2ac37e10>,
#  'enhances': <gensim.models.keyedvectors.Vocab at 0x1a2ac37e48>,
#  'reflection': <gensim.models.keyedvectors.Vocab at 0x1a2ac37e80>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x1a2ac37eb8>,
#  'peripheral': <gensim.models.keyedvectors.Vocab at 0x1a2ac37ef0>,
#  'noted': <gensim.models.keyedvectors.Vocab at 0x1a2ac37f28>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x1a2ac37f60>,
#  'peak': <gensim.models.keyedvectors.Vocab at 0x1a2ac37f98>,
#  'decreased': <gensim.models.keyedvectors.Vocab at 0x1a2ac37fd0>,
#  'casmo': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b048>,
#  'simulate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b080>,
#  'studsvik': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b0b8>,
#  'scandpower': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b0f0>,
#  'waltham': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b128>,
#  'serpent': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b160>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b198>,
#  'centre': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b1d0>,
#  'finland': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b208>,
#  'vuorimiehentie': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b240>,
#  'espoo': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b278>,
#  'stainless': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b2b0>,
#  'steel': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b2e8>,
#  'strategy': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b320>,
#  'iteration': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b358>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b390>,
#  'eigen': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b3c8>,
#  'decomposition': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b400>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b438>,
#  'cancellation': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b470>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b4a8>,
#  'stabilization': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b4e0>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b518>,
#  'accumulation': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b550>,
#  'demonstrate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b588>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b5c0>,
#  'accelerate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b5f8>,
#  'convergence': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b630>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b668>,
#  'obtaining': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b6a0>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b6d8>,
#  'summarized': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b710>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b748>,
#  'cumbersome': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b780>,
#  'polynomial': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b7b8>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b7f0>,
#  'booth': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b828>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b860>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b898>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b8d0>,
#  'inactive': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b908>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b940>,
#  'variance': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b978>,
#  'attributed': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b9b0>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x1a2ac3b9e8>,
#  'acceleration': <gensim.models.keyedvectors.Vocab at 0x1a2ac3ba20>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x1a2ac3ba58>,
#  'nonlinear': <gensim.models.keyedvectors.Vocab at 0x1a2ac3ba90>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bac8>,
#  'cmfd2n': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bb00>,
#  'proven': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bb38>,
#  'unconditionally': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bb70>,
#  'explicit': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bba8>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bbe0>,
#  'correction': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bc18>,
#  'analytic': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bc50>,
#  'nodal': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bc88>,
#  'anm2n': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bcc0>,
#  'fourier': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bcf8>,
#  'linearized': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bd30>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bd68>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bda0>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bdd8>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1a2ac3be10>,
#  'numerically': <gensim.models.keyedvectors.Vocab at 0x1a2ac3be48>,
#  'theoretical': <gensim.models.keyedvectors.Vocab at 0x1a2ac3be80>,
#  'governed': <gensim.models.keyedvectors.Vocab at 0x1a2ac3beb8>,
#  'converged': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bef0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bf28>,
#  'harmonic': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bf60>,
#  'buckling': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bf98>,
#  'contrary': <gensim.models.keyedvectors.Vocab at 0x1a2ac3bfd0>,
#  'expectation': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e048>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e080>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e0b8>,
#  'analytical': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e0f0>,
#  'derivation': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e128>,
#  'inflow': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e160>,
#  'approximation': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e198>,
#  'investigated': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e1d0>,
#  'verified': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e208>,
#  'improves': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e240>,
#  'methodology': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e278>,
#  'conventional': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e2b0>,
#  'outflow': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e2e8>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e320>,
#  'investigate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e358>,
#  'precise': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e390>,
#  'leakage': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e3c8>,
#  'anisotropic': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e400>,
#  'treating': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e438>,
#  'doubly': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e470>,
#  'heterogeneous': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e4a8>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e4e0>,
#  'compact': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e518>,
#  'grain': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e550>,
#  'dispersed': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e588>,
#  'graphite': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e5c0>,
#  'homogenizes': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e5f8>,
#  'analytically': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e630>,
#  'disadvantage': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e668>,
#  'intermediate': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e6a0>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e6d8>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e710>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e748>,
#  'infinite': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e780>,
#  'homogenized': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e7b8>,
#  'shielded': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e7f0>,
#  'bondarenko': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e828>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e860>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e898>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e8d0>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e908>,
#  'heterogeneity': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e940>,
#  'accounted': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e978>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e9b0>,
#  'definition': <gensim.models.keyedvectors.Vocab at 0x1a2ac3e9e8>,
#  ...}

# %%
totalvector = np.concatenate((docvector, wordvector), axis=0)

# %%
totalvector.shape
# Out:
# (39855, 100)

# %%
totalvector[0]
# Out:
# array([ -1.537788  ,   1.5102843 ,   0.2607431 ,   8.6123495 ,
#          9.310072  ,   3.3569167 ,  -0.57999647,   4.0813193 ,
#         -2.100814  ,   0.27252018,   2.120545  ,  -8.16783   ,
#          1.3406435 ,  -7.508276  ,   0.72170365,   5.2672496 ,
#          0.3986548 ,   6.988029  ,  -0.08896591,  -3.0488412 ,
#          6.2501483 ,   3.5094512 ,  -1.5345988 ,  -7.1269197 ,
#          2.0645022 ,   0.44854262,   1.7361653 ,  -6.3701587 ,
#          1.9195335 ,   0.874967  ,   9.752699  ,  -7.482019  ,
#         -2.8246863 ,   3.1094134 ,   3.2661924 ,   6.031913  ,
#         -1.4568621 ,  -4.7438903 ,   5.312772  ,  -3.5709686 ,
#          3.5364597 ,  -2.7800043 ,  -8.523616  ,   1.5188019 ,
#         -2.385924  ,   2.1119502 ,  -2.6473925 ,  -3.604479  ,
#          0.38303575,  -0.76028734,   4.313457  ,  -3.0957878 ,
#         -0.40347856,  -5.231018  ,   6.1418104 ,   4.9215965 ,
#         -2.0946436 ,   1.2090042 ,   1.0491024 ,   2.8800251 ,
#          0.99711394,   5.42418   ,   0.02823654,  -1.2753056 ,
#         -0.7140745 ,  -2.9707513 ,   4.617834  ,   2.831526  ,
#          0.18033989,   0.11210382,  -5.394833  , -10.052185  ,
#         -7.883345  ,  -1.842058  ,   5.6948495 , -10.838223  ,
#         -2.5823252 ,  -5.568348  ,   0.01312974,   2.815365  ,
#          0.84542185,  -4.6065426 ,   1.9721222 ,   4.608036  ,
#         -2.9458842 ,  -9.850063  ,  -1.0673219 ,   2.035111  ,
#         -7.141598  ,  -5.1819615 ,  -3.9001524 ,   1.2888834 ,
#          3.9401364 ,   1.3954042 ,  -3.2538676 ,  -0.90185237,
#          9.670224  ,  -3.518449  ,   6.5556087 ,   4.8289037 ],
#       dtype=float32)

# %%
docdict = model.docvecs.doctags

# %%
worddict = model.wv.vocab

# %%
from sklearn.metrics.pairwise import cosine_similarity
final = cosine_similarity(totalvector)

# %%
final.shape, len(final[0])
# Out:
# ((39855, 39855), 39855)

# %%
a = list(final[220])
a
# Out:
# [0.17765065,
#  0.0847393,
#  0.3652602,
#  0.11153688,
#  0.24601571,
#  0.48671854,
#  0.2726553,
#  0.2427685,
#  0.5325141,
#  0.31171632,
#  0.10240884,
#  0.46711618,
#  0.28570005,
#  0.48953724,
#  0.2661014,
#  0.44911107,
#  0.23949389,
#  0.16175808,
#  0.47830948,
#  0.12909907,
#  0.10143551,
#  0.23466884,
#  0.24965516,
#  0.41005415,
#  0.22133926,
#  0.37643665,
#  0.2247134,
#  0.095823675,
#  0.13467154,
#  0.26222315,
#  0.38955146,
#  0.2654804,
#  0.53674513,
#  0.25682586,
#  0.24557649,
#  0.2154131,
#  0.056145865,
#  0.26124796,
#  0.35032234,
#  0.11399153,
#  0.25293532,
#  0.3815723,
#  0.19395442,
#  0.25695935,
#  0.42497236,
#  0.6016654,
#  0.20329383,
#  0.41475046,
#  0.35636228,
#  0.26347294,
#  0.3273718,
#  0.22932167,
#  0.42561033,
#  0.53895277,
#  0.29840556,
#  0.35403332,
#  0.20305783,
#  0.20230305,
#  0.107252106,
#  0.3147703,
#  0.2920505,
#  0.37285867,
#  0.31642675,
#  0.27225366,
#  0.40007353,
#  0.13205369,
#  0.18856418,
#  0.25298366,
#  0.066862404,
#  0.24424338,
#  0.27902654,
#  0.16008952,
#  0.44892278,
#  0.3418028,
#  0.2439961,
#  0.4296983,
#  0.28754857,
#  0.3717316,
#  0.2790098,
#  0.104591005,
#  0.095190145,
#  0.16700196,
#  0.2351192,
#  0.5587485,
#  0.38806883,
#  0.5144504,
#  0.12277182,
#  0.11969075,
#  0.20909418,
#  0.33674023,
#  0.010979981,
#  0.1915544,
#  0.21516049,
#  0.4707099,
#  0.26345226,
#  0.095059015,
#  0.03574585,
#  0.22980072,
#  0.5081951,
#  0.31244594,
#  0.1989464,
#  0.13561185,
#  0.17298658,
#  0.45481116,
#  0.2610821,
#  0.10206623,
#  0.25841016,
#  0.09274483,
#  0.2663891,
#  0.38023686,
#  0.4406596,
#  0.40801516,
#  0.3196417,
#  0.11639379,
#  0.42929837,
#  0.24098776,
#  0.301923,
#  0.15664029,
#  0.2092212,
#  0.34097248,
#  0.26242304,
#  0.22384463,
#  0.3490766,
#  0.25663468,
#  0.48955423,
#  0.20830005,
#  0.2692122,
#  0.4852228,
#  0.27227965,
#  0.5192798,
#  0.19513556,
#  0.30680966,
#  0.4504023,
#  0.2059509,
#  0.4324746,
#  0.3667269,
#  0.14985213,
#  0.18683334,
#  0.22784455,
#  0.22836493,
#  0.16429083,
#  -0.006835384,
#  0.21028352,
#  0.22364487,
#  0.20991866,
#  0.078544706,
#  0.43682367,
#  0.20169294,
#  0.12912016,
#  0.55044264,
#  0.26371858,
#  0.5043017,
#  0.47009304,
#  0.31568,
#  0.29625627,
#  0.4480253,
#  0.41336972,
#  0.23321882,
#  0.3110524,
#  0.4013971,
#  0.5019871,
#  0.13775194,
#  0.16616923,
#  0.31549725,
#  0.29772642,
#  0.19820787,
#  0.24381196,
#  0.14984454,
#  0.2483324,
#  0.34345976,
#  0.2924227,
#  0.34345165,
#  0.14164568,
#  0.21806459,
#  0.083277285,
#  0.4380024,
#  0.4114808,
#  0.20531692,
#  0.22860996,
#  0.15125749,
#  0.17471193,
#  0.11572085,
#  0.27228948,
#  0.06856772,
#  0.48601967,
#  0.34158516,
#  0.31399897,
#  0.089678854,
#  0.18061493,
#  0.49244982,
#  0.41067153,
#  0.22620425,
#  0.2501737,
#  0.20453936,
#  0.19178236,
#  0.2668435,
#  0.084761865,
#  0.39635515,
#  0.29377288,
#  0.4536018,
#  0.3496278,
#  0.29308185,
#  0.13933802,
#  0.20463324,
#  0.27714503,
#  0.1348113,
#  0.24702553,
#  0.26700607,
#  0.4315878,
#  0.266193,
#  0.26643133,
#  0.21902613,
#  0.38590372,
#  0.507227,
#  0.2816056,
#  0.4512688,
#  0.16508864,
#  0.22984797,
#  0.3479073,
#  0.25469318,
#  1.0000001,
#  0.1822085,
#  0.38717908,
#  0.049322966,
#  0.1734613,
#  0.14705667,
#  0.06672291,
#  0.46100903,
#  0.23005125,
#  0.4147344,
#  0.16973703,
#  0.49807665,
#  0.27279684,
#  0.35947868,
#  0.33246708,
#  0.38361433,
#  0.22046526,
#  0.12120015,
#  0.06571319,
#  0.21958435,
#  0.18374865,
#  0.19536276,
#  0.15083286,
#  0.5133573,
#  0.27140746,
#  0.30536887,
#  0.3479238,
#  0.15358268,
#  0.19895653,
#  0.3701341,
#  0.31620204,
#  0.060293842,
#  0.2444981,
#  0.16706379,
#  0.23096892,
#  0.17787658,
#  0.17511119,
#  0.2861136,
#  0.028475182,
#  -0.062237464,
#  -0.0011776774,
#  0.21741849,
#  -0.0043139854,
#  -0.00022746377,
#  0.056236345,
#  0.07998459,
#  0.00040075544,
#  0.15574157,
#  0.12870128,
#  0.09844468,
#  -0.047599826,
#  0.08415295,
#  -0.021725578,
#  0.16417855,
#  0.053757098,
#  0.095697686,
#  0.11860796,
#  0.01338923,
#  -0.121618435,
#  -0.08701186,
#  0.0646839,
#  0.19010036,
#  -0.02318737,
#  0.103988804,
#  -0.06255795,
#  -0.020146387,
#  0.10429337,
#  -0.08197387,
#  -0.1014963,
#  0.00878361,
#  -0.028498081,
#  -0.015650982,
#  0.124235,
#  0.07004503,
#  0.046077803,
#  0.12478352,
#  0.07870326,
#  -0.0078874435,
#  0.10061263,
#  -0.082819395,
#  0.052808348,
#  -0.040890936,
#  0.124290034,
#  0.053825937,
#  0.14295876,
#  0.03333087,
#  -0.042293992,
#  0.0776886,
#  0.26760453,
#  0.17290136,
#  0.0716311,
#  0.08226876,
#  0.009910369,
#  -0.047711685,
#  -0.05005126,
#  0.16715853,
#  0.15536773,
#  0.08432823,
#  0.0015239324,
#  -0.05886065,
#  0.12788574,
#  0.2352586,
#  -0.052078005,
#  0.031121174,
#  0.18766658,
#  0.03573047,
#  0.14893539,
#  0.12677906,
#  0.071134545,
#  0.11314258,
#  0.046682913,
#  0.07723041,
#  -0.020803908,
#  -0.046752073,
#  -0.011265584,
#  -0.05571321,
#  0.1412617,
#  0.03258369,
#  0.16648686,
#  0.06416454,
#  0.15983148,
#  0.15101896,
#  0.13059054,
#  0.08176566,
#  0.06392114,
#  0.14621346,
#  0.024993723,
#  -0.12074981,
#  0.046233695,
#  -0.017112235,
#  -0.12790233,
#  0.05206163,
#  -0.020001763,
#  -0.044112075,
#  0.08818938,
#  0.21826695,
#  0.026491296,
#  0.085069016,
#  0.18112999,
#  0.0013940638,
#  0.18193556,
#  -0.02127855,
#  0.025618792,
#  0.09748894,
#  0.1148984,
#  0.0011952808,
#  0.01819285,
#  -0.07029096,
#  0.016029142,
#  -0.071436755,
#  0.021276992,
#  -0.0053807613,
#  0.20476499,
#  0.10306362,
#  0.039966255,
#  -0.032721814,
#  -0.00014530621,
#  0.11828076,
#  0.054894358,
#  0.1596135,
#  0.052089427,
#  0.01061429,
#  0.096411526,
#  0.101665236,
#  0.1358628,
#  0.1767304,
#  0.02181142,
#  0.117374174,
#  0.13234378,
#  0.11189492,
#  -0.046938866,
#  0.16078985,
#  0.067772724,
#  -0.01224533,
#  0.13593346,
#  0.084973164,
#  0.11578328,
#  0.105380334,
#  0.101732984,
#  0.0958589,
#  0.030842563,
#  0.1715546,
#  -0.0057121515,
#  0.14782818,
#  0.05849496,
#  0.024130426,
#  0.13350026,
#  0.08525081,
#  0.04007201,
#  0.059675492,
#  0.011175233,
#  -0.0037890838,
#  0.14317888,
#  0.054530274,
#  0.057481892,
#  -0.007629034,
#  0.046638463,
#  0.13625005,
#  -0.013397276,
#  -0.030661289,
#  -0.00025248446,
#  0.15161105,
#  0.11286686,
#  0.1317857,
#  -0.06322624,
#  0.0166556,
#  0.030150324,
#  0.0018890635,
#  -0.016843652,
#  0.099390335,
#  0.012198104,
#  -0.0017076032,
#  0.049631033,
#  0.021959929,
#  0.053691436,
#  0.04846939,
#  0.19250335,
#  -0.02611613,
#  0.056383334,
#  0.04722113,
#  -0.024604097,
#  0.061397962,
#  0.0528553,
#  -0.0049504447,
#  -0.060234364,
#  0.05493801,
#  0.07964409,
#  0.07043916,
#  0.09217104,
#  0.14668483,
#  0.08448769,
#  0.15881658,
#  -0.05616602,
#  0.12341691,
#  0.08360247,
#  0.13118862,
#  0.0031723124,
#  0.15312922,
#  0.09784768,
#  -0.025763255,
#  0.052520048,
#  -0.0017956811,
#  -0.01281859,
#  -0.0628715,
#  0.014083034,
#  -0.045601856,
#  0.13108139,
#  0.025178358,
#  -0.012050056,
#  0.06757901,
#  0.12726396,
#  -0.01757136,
#  0.08807664,
#  -0.050213944,
#  0.04355444,
#  -0.065952875,
#  0.063187264,
#  0.13737556,
#  0.116279416,
#  0.11757103,
#  -0.00925228,
#  -0.12665577,
#  -0.17082787,
#  0.18159214,
#  0.12806787,
#  0.24564788,
#  0.0002514483,
#  0.152745,
#  0.27188656,
#  -0.0013680449,
#  -0.034712993,
#  0.17818439,
#  0.07540965,
#  0.021586437,
#  -0.11150777,
#  -0.0470698,
#  0.030747546,
#  -0.06545766,
#  -0.021715237,
#  -0.048624214,
#  0.14143513,
#  0.104280084,
#  -0.17182946,
#  0.11958913,
#  0.33029068,
#  0.097073436,
#  -0.006930876,
#  0.08470298,
#  0.17314263,
#  0.1013441,
#  0.103785194,
#  0.21934474,
#  -0.1838369,
#  0.019935181,
#  -0.012693647,
#  -0.02816534,
#  0.050113995,
#  0.01164512,
#  0.026158813,
#  0.09814367,
#  0.12536776,
#  0.0980172,
#  -0.032288518,
#  0.09284338,
#  0.21167788,
#  0.06688755,
#  0.014841492,
#  0.10166845,
#  0.11955896,
#  0.006881084,
#  -0.16168025,
#  0.033403832,
#  -0.03422023,
#  0.076287866,
#  -0.007055339,
#  0.09118679,
#  -0.12841448,
#  0.14530168,
#  -0.040245093,
#  0.061356496,
#  -0.0059965043,
#  0.17813385,
#  0.18012506,
#  0.03310414,
#  0.022370646,
#  0.016736437,
#  -0.033529725,
#  0.07663045,
#  0.15619287,
#  -0.07090884,
#  0.043053757,
#  -0.052547917,
#  0.10331973,
#  0.022613803,
#  0.12376084,
#  0.048704874,
#  0.11173986,
#  0.0012123901,
#  -0.07069231,
#  -0.06425525,
#  0.10510335,
#  0.15054986,
#  -0.023996951,
#  0.047649175,
#  -0.023306558,
#  -0.0051394748,
#  0.062666185,
#  0.043660033,
#  0.03239798,
#  0.07692351,
#  0.15493824,
#  0.19255477,
#  -0.036791816,
#  0.04031574,
#  0.15106304,
#  0.06204793,
#  0.07292191,
#  -0.008215916,
#  0.09269506,
#  0.050415132,
#  0.028916147,
#  -0.09163853,
#  -0.04888315,
#  0.21991324,
#  0.056937374,
#  0.05658492,
#  -0.09662752,
#  0.13286182,
#  -0.069395244,
#  0.20987616,
#  0.12794511,
#  0.058818787,
#  0.18261668,
#  0.088639654,
#  0.0751238,
#  -0.06881821,
#  -0.03389298,
#  0.10572662,
#  0.19030802,
#  0.068370454,
#  -0.018761838,
#  0.12977712,
#  -0.1476568,
#  0.0040601077,
#  0.022543397,
#  -0.025104243,
#  0.15848449,
#  0.13996351,
#  0.19737649,
#  0.082765885,
#  0.1339292,
#  0.11648126,
#  0.09075536,
#  0.11823133,
#  0.1137486,
#  -0.16132759,
#  0.19890873,
#  0.024962211,
#  0.13767505,
#  0.028162478,
#  0.16206259,
#  0.0389341,
#  0.09962672,
#  0.04023311,
#  0.074046746,
#  0.10885834,
#  0.09529618,
#  -0.10581806,
#  0.17377749,
#  0.1603381,
#  0.055351604,
#  0.13177472,
#  0.12674038,
#  0.0011899688,
#  -0.03233135,
#  -0.06317209,
#  0.121369086,
#  0.1404798,
#  0.018003011,
#  0.19166842,
#  0.030159488,
#  -0.10066539,
#  0.08832422,
#  0.14124574,
#  -0.121378176,
#  0.029455232,
#  -0.06120215,
#  0.045242812,
#  0.13217548,
#  0.06318927,
#  0.17270969,
#  0.12030584,
#  -0.028931558,
#  0.06676271,
#  -0.06539541,
#  0.10380955,
#  -0.12453745,
#  0.074894615,
#  0.041562658,
#  0.24478787,
#  -0.008189481,
#  0.13401681,
#  0.006549011,
#  0.0455728,
#  0.06883524,
#  -0.054914158,
#  0.13033603,
#  0.07715731,
#  0.12009907,
#  -0.015817823,
#  0.06946412,
#  0.16172282,
#  0.07842244,
#  0.023437934,
#  0.096706845,
#  0.08800867,
#  0.05301249,
#  0.1270863,
#  0.061509445,
#  0.09360658,
#  -0.0031799981,
#  0.1267284,
#  -0.00241141,
#  -0.21153082,
#  -0.051594842,
#  0.13421099,
#  -0.10090756,
#  -0.027699893,
#  -0.15343912,
#  0.03750099,
#  -0.02106258,
#  0.06270973,
#  0.06285208,
#  0.025416527,
#  0.095813625,
#  -0.13914594,
#  0.056611516,
#  -0.0057655093,
#  0.24916972,
#  0.048168007,
#  0.08061288,
#  0.16839734,
#  0.13063164,
#  0.13032167,
#  -0.018246742,
#  0.20703395,
#  0.25981,
#  0.11864524,
#  0.0186631,
#  0.15094087,
#  -0.007883005,
#  -0.0072011715,
#  -0.060848556,
#  0.03774101,
#  0.025521738,
#  -0.011587912,
#  0.03882456,
#  -0.047760714,
#  -0.0011072853,
#  0.1392795,
#  0.06545048,
#  0.07435517,
#  0.050570454,
#  0.0866892,
#  0.16846244,
#  0.055053804,
#  0.12224209,
#  0.06803397,
#  -0.06231172,
#  0.16842672,
#  0.09433076,
#  0.31920576,
#  0.06771448,
#  0.08914958,
#  0.12574658,
#  -0.033996824,
#  0.09551485,
#  0.1496021,
#  0.18605171,
#  0.20974416,
#  0.15075836,
#  0.0592342,
#  0.2304948,
#  0.21354532,
#  0.09604136,
#  -0.07558953,
#  -0.084609374,
#  -0.12819706,
#  0.070491634,
#  0.09263098,
#  -0.021489114,
#  0.23609203,
#  0.016540749,
#  -0.06686316,
#  0.077018805,
#  0.0909801,
#  0.0933712,
#  -0.08441689,
#  0.03685027,
#  0.14065464,
#  0.22028205,
#  0.10154933,
#  0.025439767,
#  0.055546075,
#  0.10422831,
#  0.050130863,
#  0.0032954658,
#  0.041212544,
#  0.18470624,
#  0.10751579,
#  0.0038649847,
#  -0.014968715,
#  -0.049654868,
#  -0.17578153,
#  0.03564232,
#  0.03170857,
#  0.1566448,
#  -0.043741785,
#  -0.082508914,
#  -0.010389221,
#  0.09407828,
#  0.292589,
#  0.114712864,
#  0.15345356,
#  0.07533793,
#  0.07594637,
#  -0.12910916,
#  0.26071742,
#  -0.003675007,
#  0.2764998,
#  -0.023638379,
#  0.023156635,
#  0.26946595,
#  0.32212552,
#  0.07045772,
#  0.15662377,
#  0.29653817,
#  0.15038626,
#  0.15263505,
#  0.038310934,
#  0.15752901,
#  -0.029728925,
#  -0.101664394,
#  0.03186085,
#  0.09518947,
#  0.14544114,
#  -0.096085235,
#  0.04433566,
#  0.13713235,
#  -0.044501554,
#  0.21100003,
#  0.14824705,
#  0.023475917,
#  0.06381404,
#  0.118240945,
#  0.2357739,
#  0.085402794,
#  0.005323964,
#  0.02840562,
#  -0.09994443,
#  0.046933267,
#  0.0054391404,
#  0.12807633,
#  0.16554645,
#  0.24488002,
#  0.08295504,
#  0.07240706,
#  -0.021635516,
#  0.118637815,
#  -0.0194227,
#  0.03341016,
#  0.028764732,
#  0.12044017,
#  -0.040074203,
#  ...]

# %%
b

# %%
for i,j in zip(final,docdict):
    print(i,j)
    break
# Out:
# [ 1.          0.1293726   0.13088992 ... -0.07073579  0.28828058
#   0.11490185] Lee, Deokjung(이덕중)

# %%
for i in docdict:
    print(i)
    break
# Out:
# Lee, Deokjung(이덕중)

# %%
for i in docdict:
    documents = {}
    documents['profname'] = i
    db.profname.insert_one(documents)

# %%
for i in worddict:
    documents = {}
    documents['wordname'] = i
    db.wordname.insert_one(documents)

# %%
for i in final:
    documents = {}
    documents['vector'] = i.tolist()
    db.vector.insert_one(documents)

# %%
db.vector.find_one()
# Out:
# {'_id': ObjectId('5bf841df20c66c02a7b84ecb'),
#  'vector': [1.0,
#   0.12937259674072266,
#   0.1308899223804474,
#   0.188479483127594,
#   0.10785772651433945,
#   0.1710975617170334,
#   0.1708911508321762,
#   0.15522992610931396,
#   0.24396102130413055,
#   0.15395788848400116,
#   0.12821738421916962,
#   0.34628888964653015,
#   0.13102073967456818,
#   0.17778272926807404,
#   0.2334497720003128,
#   0.24668854475021362,
#   0.24013002216815948,
#   0.44771337509155273,
#   0.2519058883190155,
#   0.15163105726242065,
#   0.2225780189037323,
#   0.08745457977056503,
#   0.15946051478385925,
#   0.21051301062107086,
#   0.16481298208236694,
#   0.1557459980249405,
#   0.11552534252405167,
#   0.11630631983280182,
#   0.1235044077038765,
#   0.33423614501953125,
#   0.32820406556129456,
#   0.10171123594045639,
#   0.12799552083015442,
#   0.08880387991666794,
#   0.19626955687999725,
#   0.10253062099218369,
#   0.3134538531303406,
#   0.1933235228061676,
#   0.36798542737960815,
#   0.09213367849588394,
#   0.03062453120946884,
#   0.24506720900535583,
#   0.2650868594646454,
#   0.40881314873695374,
#   0.23360824584960938,
#   0.1814865916967392,
#   0.23577556014060974,
#   0.20178954303264618,
#   0.16979466378688812,
#   0.09250248968601227,
#   0.15128584206104279,
#   0.19117788970470428,
#   0.34076225757598877,
#   0.16409149765968323,
#   0.23809470236301422,
#   0.2716716527938843,
#   0.14622193574905396,
#   0.12505997717380524,
#   0.13707074522972107,
#   0.26353031396865845,
#   0.2597949504852295,
#   0.23613809049129486,
#   0.04460068419575691,
#   0.2038213014602661,
#   0.21237806975841522,
#   0.21318337321281433,
#   0.15613459050655365,
#   -0.04254012554883957,
#   0.12969908118247986,
#   0.2346612960100174,
#   0.12438109517097473,
#   0.18940632045269012,
#   0.3164578378200531,
#   0.35609155893325806,
#   0.24914415180683136,
#   0.30552512407302856,
#   0.14732041954994202,
#   0.04095509648323059,
#   0.27429747581481934,
#   0.14144596457481384,
#   0.14656278491020203,
#   0.1913428157567978,
#   0.1310381293296814,
#   0.28158119320869446,
#   -0.01484253816306591,
#   0.15617217123508453,
#   0.23466849327087402,
#   0.14490361511707306,
#   0.48486992716789246,
#   0.3970458507537842,
#   0.20550107955932617,
#   0.19753862917423248,
#   0.07370070368051529,
#   0.14160294830799103,
#   0.269763320684433,
#   0.17502155900001526,
#   0.08663840591907501,
#   0.18048831820487976,
#   0.3013038635253906,
#   0.41360780596733093,
#   0.15125417709350586,
#   0.5100983381271362,
#   0.01870722696185112,
#   0.16081251204013824,
#   0.2384832352399826,
#   0.21743352711200714,
#   0.3582119047641754,
#   0.4262695610523224,
#   0.1182246133685112,
#   0.2729387581348419,
#   0.3242574632167816,
#   0.271856427192688,
#   0.21083034574985504,
